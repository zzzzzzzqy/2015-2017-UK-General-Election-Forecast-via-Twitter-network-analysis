# %%
# Here are the libraries I am using
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from os import path
import json
import csv
import twitter

# %%
api = twitter.Api(consumer_key='VMEtmluCX5kbgdpxVGCQpKsU3',
                  consumer_secret='EE7IAgm84rzEaMYmxzDVFRqc0VG5TPCQ91PaExgn9tkv8WdrJ7',
                  access_token_key='894677768465731586-w4kRfckM6aRHvdEPwX7ycYCCXc9a2Y1',
                  access_token_secret='aup3PMyri8zRV66XKBcThxO08HSA3PSZfWvdKseC5JEPq',
                 sleep_on_rate_limit=True)

# %%
def get_last_create_time(statuses):
    if len(statuses) <= 1:
        return '0', '0'
    else:
        return statuses[-1].id, statuses[-1].created_at[-4:]

def usercrawler(userid = 72531619):
    print('id: {} start..'.format(userid))
    count = 0
    statuses = api.GetUserTimeline(user_id= userid, screen_name=None, since_id=None, max_id=None, count=200, include_rts=True, trim_user=False, exclude_replies=False)
    count += len(statuses)
    last_id, created_time = get_last_create_time(statuses)
    print('id: {}, count: {}, last_id: {}'.format(userid, count, last_id))
    if len(statuses) <= 1:
        print('id: {} done with {} status'.format(userid, count))
        return 
    else:
        with open("crawler.json","a") as f:
            for t in statuses:
                if t.created_at[-4:] >= '2014':
                    json.dump(t._json,f)
                    f.write('\n')
  
    while created_time >='2014' and len(statuses) > 0:
        statuses = api.GetUserTimeline(user_id=userid, 
                                       screen_name=None, 
                                       since_id=None, 
                                       max_id= last_id, 
                                       count=200, include_rts=True, 
                                       trim_user=False, exclude_replies=False)
        count += len(statuses)
        last_id, created_time = get_last_create_time(statuses)
        print('id: {}, count: {}, last_id: {}'.format(userid, count, last_id))
        if len(statuses) <= 1:
            break
        with open("crawler.json","a") as f:
            for t in statuses:
                if t.created_at[-4:] < '2014':
                    break         
                else:
                    json.dump(t._json, f)
                    f.write('\n')
    print('id: {} done with {} status'.format(userid, count))

# %%
#delet repeat data
s = []
[ s.append(k) for k in open('crawler.json') if k not in s ]
open('set_crawler.json', 'w').write(''.join(s))

# %%
dataset = []
with open('set_crawler.txt', 'r') as file:
    count = 0
    for line in file:
        count += 1
        dataset.append(json.loads(line))
        print(count)
print(len(dataset))

# %%
dataset[0]

# %%
csv_out = open('tweets_out_ASCII.csv', mode='w', newline='') #opens csv file
writer = csv.writer(csv_out) #create the csv writer object
 
fields = ['created_at', 'text', 'screen_name', 'followers', 'friends', 'rt', 'fav','mentioned', 'quoted', 'reweet'] #field names
writer.writerow(fields) #writes field

for line in dataset:
    
    #writes a row and gets the fields from the json object
    #screen_name and followers/friends are found on the second level hence two get methods
    writer.writerow([line.get('created_at'),
                     line.get('text').encode('unicode_escape'), #unicode escape to fix emoji issue
                     line.get('user').get('screen_name'),
                     line.get('user').get('followers_count'),
                     line.get('user').get('friends_count'),
                     line.get('retweet_count'),
                     line.get('favorite_count'),
                     line.get('entities').get('user_mentions')[0].get('name') if line.get('entities').get('user_mentions') != [] else None,
                     line.get('quoted_status').get('user').get('name', 'None') if line.get('quoted_status') != None else None,
                
                     line.get('retweeted_status').get('user').get('name', 'None') if line.get('retweeted_status') != None else None
                    ])
 
csv_out.close()

# %%
df = pd.read_csv('tweets_out_ASCII.csv')

# %%
df.head(100)

# %%
api.GetUser(screen_name = 'wetransmute')

# %%
api.GetLists(user_id=2429258599, screen_name='wetransmute')

# %%
LIST_MP_15 = api.GetListMembers(list_id=196583411, slug=None, owner_id=2429258599, 
                                owner_screen_name='wetransmute', skip_status=False, 
                                include_entities=False)

# %%
type(LIST_MP_15)

# %%
LIST_MP_15

# %%
LIST_MP_15_ids = [u.id for u in LIST_MP_15]

# %%
LIST_MP_15_ids

# %%
def get_last_create_time(statuses):
    if len(statuses) <= 1:
        return '0', '0'
    else:
        return statuses[-1].id, statuses[-1].created_at[-4:]

def usercrawler_17(userid = 72531619):
    print('id: {} start..'.format(userid))
    count = 0
    try:
        statuses = api.GetUserTimeline(user_id= userid, screen_name=None, since_id=None, max_id=872692782082740226, count=200, include_rts=True, trim_user=False, exclude_replies=False)
    except:
        print(str(userid) + ' with error')
        return
    count += len(statuses)
    last_id, created_time = get_last_create_time(statuses)
    print('id: {}, count: {}, last_id: {}'.format(userid, count, last_id))
    if len(statuses) <= 1:
        print('id: {} done with {} status'.format(userid, count))
        return 
    else:
        with open("crawler17.json","a") as f:
            for t in statuses:
                if t.created_at[-4:] >= '2016':
                    json.dump(t._json,f)
                    f.write('\n')
  
    while created_time >='2016' and len(statuses) > 0:
        statuses = api.GetUserTimeline(user_id=userid, 
                                       screen_name=None, 
                                       since_id=None, 
                                       max_id= last_id, 
                                       count=200, include_rts=True, 
                                       trim_user=False, exclude_replies=False)
        count += len(statuses)
        last_id, created_time = get_last_create_time(statuses)
        print('id: {}, count: {}, last_id: {}'.format(userid, count, last_id))
        if len(statuses) <= 1:
            break
        with open("crawler17.json","a") as f:
            for t in statuses:
                if t.created_at[-4:] < '2016':
                    break         
                else:
                    json.dump(t._json, f)
                    f.write('\n')
    print('id: {} done with {} status'.format(userid, count))

# %%
api.GetUser(screen_name = 'GutoAberconwy')
# Out:
# User(ID=752820350371717120, ScreenName=GutoAberconwy)

# %%
usercrawler_17(userid = 722347303)
# Out:
# id: 722347303 start..
# id: 722347303, count: 200, last_id: 879822539177984000
# id: 722347303, count: 400, last_id: 866668513330692096
# id: 722347303, count: 600, last_id: 846726730412908546
# id: 722347303, count: 797, last_id: 834898698077417474
# id: 722347303, count: 996, last_id: 823500860814749697
# id: 722347303, count: 1196, last_id: 804705360128970752
# id: 722347303, count: 1396, last_id: 783628261989449728
# id: 722347303, count: 1596, last_id: 772850974427848704
# id: 722347303, count: 1796, last_id: 751337208410411009
# id: 722347303, count: 1996, last_id: 736570862980202496
# id: 722347303, count: 2193, last_id: 725612261243510784
# id: 722347303, count: 2392, last_id: 715586673602592768
# id: 722347303, count: 2591, last_id: 703227769459703808
# id: 722347303, count: 2790, last_id: 692031606735966208
# id: 722347303, count: 2989, last_id: 673976206337929216
# id: 722347303 done with 2989 status

# %% [markdown]
# ## SELECTED PARTIES: Conservatives, Labour and Liberal Democrats

# %%
df_2017_SP = pd.read_csv('2017_SP_candidates.csv')

# %%
df_2017_SP.head(10)
# Out:
#    Unnamed: 0             name  gender  birth_date  \
# 0           2  Stephen Kinnock    male  1970-01-01
# 1           3     Cen Phillips    male        1971
# 2           4      Sadie Vidal  female         NaN
# 3           5        Guto Bebb    male  1968-10-09
# 4           8       Emily Owen  Female        1995
# 5          10  Isobel Davidson  female         NaN
# 6          12   Grace O'Keeffe  female         NaN
# 7          13     Orr Vinegold    male        1988
# 8          15   Callum O'Dwyer    Male         NaN
# 9          16     Ross Thomson    male  1987-09-21
#
#                         party_name      post_label elected twitter_username  \
# 0                     Labour Party        Aberavon    True         SKinnock
# 1                Liberal Democrats        Aberavon   False            CenLD
# 2  Conservative and Unionist Party        Aberavon   False       sadievidal
# 3  Conservative and Unionist Party       Aberconwy    True    GutoAberconwy
# 4                     Labour Party       Aberconwy   False  Emily4Aberconwy
# 5                Liberal Democrats  Aberdeen North   False   isobeldavidson
# 6  Conservative and Unionist Party  Aberdeen North   False  Grace_E_OKeeffe
# 7                     Labour Party  Aberdeen North   False   OrrVinegoldLab
# 8                     Labour Party  Aberdeen South   False    callumjodwyer
# 9  Conservative and Unionist Party  Aberdeen South    True   RossThomson_MP
#
#       twitter_user_id
# 0           722347303
# 1          1872769464
# 2            19447175
# 3  752820350371717120
# 4            92363214
# 5          1553831654
# 6  858789131622723584
# 7  857290145795641344
# 8            65415768
# 9           539849453

# %%
list_id_2017_SP = df_2017_SP.twitter_user_id.tolist()

# %%
len(list_id_2017_SP)
# Out:
# 1455

# %%
list_id_2017_SP[19]
count = 19

# %%
for _id in list_id_2017_SP[count:-1]:
    print(count)
    usercrawler_17(userid = _id)
    count += 1
# Out:
# 948
# id: 36924726 start..
# id: 36924726, count: 199, last_id: 869934431536021504
# id: 36924726, count: 399, last_id: 863392605027094528
# id: 36924726, count: 597, last_id: 857318740928712704
# id: 36924726, count: 795, last_id: 853685241285943297
# id: 36924726, count: 994, last_id: 846767816174981120
# id: 36924726, count: 1194, last_id: 839379146870501376
# id: 36924726, count: 1392, last_id: 826463279526576128
# id: 36924726, count: 1592, last_id: 822814945951838209
# id: 36924726, count: 1789, last_id: 817095461274259456
# id: 36924726, count: 1989, last_id: 808278662147670016
# id: 36924726, count: 2188, last_id: 805163827679653889
# id: 36924726, count: 2387, last_id: 800484381840248833
# id: 36924726, count: 2585, last_id: 795390911505108996
# id: 36924726, count: 2615, last_id: 794235621875261440
# id: 36924726, count: 2616, last_id: 0
# id: 36924726 done with 2616 status
# 949
# id: 2819552283 start..
# id: 2819552283, count: 200, last_id: 824753140587233281
# id: 2819552283, count: 399, last_id: 753842320160673792
# id: 2819552283, count: 599, last_id: 667657427869966336
# id: 2819552283 done with 599 status
# 950
# id: 117597342 start..
# id: 117597342, count: 200, last_id: 860153646658584576
# id: 117597342, count: 400, last_id: 813371153100193792
# id: 117597342, count: 600, last_id: 786517395703754752
# id: 117597342, count: 798, last_id: 777452737432784896
# id: 117597342, count: 997, last_id: 739548592441036800
# id: 117597342, count: 1196, last_id: 732977038542393344
# id: 117597342, count: 1395, last_id: 728884336154554368
# id: 117597342, count: 1593, last_id: 718448166551556096
# id: 117597342, count: 1790, last_id: 712158044193497088
# id: 117597342, count: 1989, last_id: 701073994913550336
# id: 117597342, count: 2189, last_id: 694108926435069953
# id: 117597342, count: 2387, last_id: 687223245200879616
# id: 117597342, count: 2584, last_id: 684016479176667138
# id: 117597342, count: 2784, last_id: 681891208659136512
# id: 117597342 done with 2784 status
# 951
# id: 742549488 start..
# id: 742549488, count: 200, last_id: 550033225020891141
# id: 742549488 done with 200 status
# 952
# id: 20148039 start..
# id: 20148039, count: 200, last_id: 870306569568890880
# id: 20148039, count: 400, last_id: 866266857208205313
# id: 20148039, count: 600, last_id: 862770398060064768
# id: 20148039, count: 800, last_id: 858293345810083840
# id: 20148039, count: 1000, last_id: 852531415002619905
# id: 20148039, count: 1200, last_id: 848066869932249089
# id: 20148039, count: 1400, last_id: 840611431703797760
# id: 20148039, count: 1600, last_id: 835431151074410496
# id: 20148039, count: 1800, last_id: 831994424263577600
# id: 20148039, count: 2000, last_id: 826133333696462851
# id: 20148039, count: 2200, last_id: 819649374154358784
# id: 20148039, count: 2400, last_id: 807140924581089280
# id: 20148039, count: 2600, last_id: 797748368579629056
# id: 20148039, count: 2722, last_id: 793882555225370628
# id: 20148039, count: 2723, last_id: 0
# id: 20148039 done with 2723 status
# 953
# id: 36154400 start..
# id: 36154400, count: 199, last_id: 635120248753139712
# id: 36154400 done with 199 status
# 954
# id: 128590458 start..
# id: 128590458, count: 19, last_id: 11431421477
# id: 128590458 done with 19 status
# 955
# id: 859724124402458624 start..
# 859724124402458624 with error
# 956
# id: 516869385 start..
# id: 516869385, count: 200, last_id: 787921732354977792
# id: 516869385, count: 397, last_id: 650377568181428224
# id: 516869385 done with 397 status
# 957
# id: 1469686752 start..
# id: 1469686752, count: 200, last_id: 844645166443122689
# id: 1469686752, count: 400, last_id: 778531558126911488
# id: 1469686752, count: 600, last_id: 745866431066152960
# id: 1469686752, count: 798, last_id: 716979727622414337
# id: 1469686752, count: 997, last_id: 677381827837997056
# id: 1469686752 done with 997 status
# 958
# id: 3072168695 start..
# id: 3072168695, count: 200, last_id: 859090816656187392
# id: 3072168695, count: 400, last_id: 783297329935810560
# id: 3072168695, count: 597, last_id: 596372930738683904
# id: 3072168695 done with 597 status
# 959
# id: 231948144 start..
# id: 231948144, count: 197, last_id: 855002045534937088
# id: 231948144, count: 393, last_id: 696769533248413696
# id: 231948144, count: 592, last_id: 639768865212399616
# id: 231948144 done with 592 status
# 960
# id: 551787654 start..
# 551787654 with error
# 961
# id: 169898513 start..
# id: 169898513, count: 200, last_id: 858776137471864836
# id: 169898513, count: 400, last_id: 843865667522707458
# id: 169898513, count: 600, last_id: 836267536836673537
# id: 169898513, count: 799, last_id: 824271809067499521
# id: 169898513, count: 999, last_id: 809501534769860608
# id: 169898513, count: 1199, last_id: 801403275346083840
# id: 169898513, count: 1399, last_id: 789513352368226305
# id: 169898513, count: 1599, last_id: 781143227038597120
# id: 169898513, count: 1799, last_id: 769161445288345600
# id: 169898513, count: 1998, last_id: 759008799705358336
# id: 169898513, count: 2197, last_id: 748885544558534656
# id: 169898513, count: 2396, last_id: 738040800186138625
# id: 169898513, count: 2555, last_id: 731208350902456322
# id: 169898513, count: 2556, last_id: 0
# id: 169898513 done with 2556 status
# 962
# id: 27718919 start..
# id: 27718919, count: 0, last_id: 0
# id: 27718919 done with 0 status
# 963
# id: 4285605677 start..
# id: 4285605677, count: 34, last_id: 672071280988971009
# id: 4285605677 done with 34 status
# 964
# id: 92498317 start..
# id: 92498317, count: 199, last_id: 755464634459643904
# id: 92498317, count: 399, last_id: 691725573417259009
# id: 92498317, count: 599, last_id: 598931132290301952
# id: 92498317 done with 599 status
# 965
# id: 15975081 start..
# id: 15975081, count: 200, last_id: 865937798389485570
# id: 15975081, count: 327, last_id: 860823274451857409
# id: 15975081, count: 328, last_id: 0
# id: 15975081 done with 328 status
# 966
# id: 83712796 start..
# id: 83712796, count: 199, last_id: 825412311322079232
# id: 83712796, count: 399, last_id: 791054433169932289
# id: 83712796, count: 599, last_id: 753110969967054848
# id: 83712796, count: 797, last_id: 696284767713681408
# id: 83712796, count: 997, last_id: 647831366344835072
# id: 83712796 done with 997 status
# 967
# id: 225857392 start..
# id: 225857392, count: 200, last_id: 868221803168182273
# id: 225857392, count: 400, last_id: 861649291571580932
# id: 225857392, count: 599, last_id: 855724223574286337
# id: 225857392, count: 799, last_id: 851396013751455748
# id: 225857392, count: 999, last_id: 844889876038340609
# id: 225857392, count: 1199, last_id: 840310337895309312
# id: 225857392, count: 1399, last_id: 836169283579293696
# id: 225857392, count: 1599, last_id: 831919789522243587
# id: 225857392, count: 1799, last_id: 827071358030979073
# id: 225857392, count: 1999, last_id: 823191680614539264
# id: 225857392, count: 2199, last_id: 818111809257349126
# id: 225857392, count: 2287, last_id: 814867667802816514
# id: 225857392, count: 2288, last_id: 0
# id: 225857392 done with 2288 status
# 968
# id: 859461705335623680 start..
# id: 859461705335623680, count: 58, last_id: 862560414944468992
# id: 859461705335623680, count: 59, last_id: 0
# id: 859461705335623680 done with 59 status
# 969
# id: 430299812 start..
# id: 430299812, count: 200, last_id: 857691875397992448
# id: 430299812, count: 400, last_id: 780067420346183680
# id: 430299812, count: 600, last_id: 695186631226179584
# id: 430299812, count: 800, last_id: 612965342294446080
# id: 430299812 done with 800 status
# 970
# id: 4705368149 start..
# id: 4705368149, count: 141, last_id: 684144120529563648
# id: 4705368149, count: 142, last_id: 0
# id: 4705368149 done with 142 status
# 971
# id: 91786287 start..
# id: 91786287, count: 200, last_id: 776745173762076672
# id: 91786287, count: 400, last_id: 744496586647035904
# id: 91786287, count: 600, last_id: 738670706750324736
# id: 91786287, count: 800, last_id: 730293884543238144
# id: 91786287, count: 1000, last_id: 712629068613742592
# id: 91786287, count: 1200, last_id: 555683221984518144
# id: 91786287 done with 1200 status
# 972
# id: 115494227 start..
# id: 115494227, count: 200, last_id: 868880987400306690
# id: 115494227, count: 398, last_id: 862568737391730688
# id: 115494227, count: 597, last_id: 856425446069727233
# id: 115494227, count: 797, last_id: 847762150265376768
# id: 115494227, count: 997, last_id: 841793543983243264
# id: 115494227, count: 1197, last_id: 837285140141326336
# id: 115494227, count: 1396, last_id: 830912759814569986
# id: 115494227, count: 1596, last_id: 825458406861463556
# id: 115494227, count: 1792, last_id: 815874841106612224
# id: 115494227, count: 1992, last_id: 804101666903617537
# id: 115494227, count: 2190, last_id: 794957445869277184
# id: 115494227, count: 2390, last_id: 782635852618948608
# id: 115494227, count: 2590, last_id: 774559656467435520
# id: 115494227, count: 2789, last_id: 765990400289038336
# id: 115494227, count: 2987, last_id: 752894152849887233
# id: 115494227, count: 3050, last_id: 751127404618407936
# id: 115494227, count: 3051, last_id: 0
# id: 115494227 done with 3051 status
# 973
# id: 5733842 start..
# id: 5733842, count: 199, last_id: 860824947991687168
# id: 5733842, count: 398, last_id: 834310378473537536
# id: 5733842, count: 590, last_id: 816666873328783360
# id: 5733842, count: 786, last_id: 799581496164151296
# id: 5733842, count: 982, last_id: 789175743481655298
# id: 5733842, count: 1178, last_id: 779737677851684864
# id: 5733842, count: 1376, last_id: 762658543984050176
# id: 5733842, count: 1573, last_id: 734834764335730688
# id: 5733842, count: 1771, last_id: 658393583163150336
# id: 5733842 done with 1771 status
# 974
# id: 478891321 start..
# id: 478891321, count: 2, last_id: 551302595008921600
# id: 478891321 done with 2 status
# 975
# id: 237700394 start..
# id: 237700394, count: 200, last_id: 819874048482181121
# id: 237700394, count: 400, last_id: 776879300532371457
# id: 237700394, count: 599, last_id: 732485399658946561
# id: 237700394, count: 799, last_id: 687991206610092032
# id: 237700394, count: 999, last_id: 614152411016507397
# id: 237700394 done with 999 status
# 976
# id: 140594592 start..
# id: 140594592, count: 200, last_id: 820372573452124160
# id: 140594592, count: 400, last_id: 745986272334872576
# id: 140594592, count: 600, last_id: 651336014355689472
# id: 140594592 done with 600 status
# 977
# id: 2978109879 start..
# id: 2978109879, count: 200, last_id: 861938953896808449
# id: 2978109879, count: 400, last_id: 836618243095814144
# id: 2978109879, count: 600, last_id: 807603679822024705
# id: 2978109879, count: 800, last_id: 782919486932447232
# id: 2978109879, count: 999, last_id: 748451821874712576
# id: 2978109879, count: 1198, last_id: 713452258269106176
# id: 2978109879, count: 1397, last_id: 673140980325949440
# id: 2978109879 done with 1397 status
# 978
# id: 60585651 start..
# id: 60585651, count: 200, last_id: 842350246663491585
# id: 60585651, count: 400, last_id: 815174218476298240
# id: 60585651, count: 600, last_id: 793468212826570752
# id: 60585651, count: 799, last_id: 773853059495686144
# id: 60585651, count: 999, last_id: 746109871486021632
# id: 60585651, count: 1199, last_id: 710848204011655169
# id: 60585651, count: 1399, last_id: 661937084647792640
# id: 60585651 done with 1399 status
# 979
# id: 23424533 start..
# id: 23424533, count: 200, last_id: 864875896599179264
# id: 23424533, count: 400, last_id: 833239464591884290
# id: 23424533, count: 600, last_id: 768523333826666500
# id: 23424533, count: 800, last_id: 719813725050548225
# id: 23424533, count: 1000, last_id: 633189916621582336
# id: 23424533 done with 1000 status
# 980
# id: 243135658 start..
# id: 243135658, count: 193, last_id: 310511856521457664
# id: 243135658 done with 193 status
# 981
# id: 861333913695924224 start..
# 861333913695924224 with error
# 982
# id: 461140983 start..
# id: 461140983, count: 196, last_id: 655111328978202624
# id: 461140983 done with 196 status
# 983
# id: 250313359 start..
# id: 250313359, count: 199, last_id: 829769890189942784
# id: 250313359, count: 399, last_id: 744976754742280192
# id: 250313359, count: 597, last_id: 710564379268358145
# id: 250313359, count: 795, last_id: 667655671211565056
# id: 250313359 done with 795 status
# 984
# id: 131517399 start..
# id: 131517399, count: 200, last_id: 861825420865482753
# id: 131517399, count: 400, last_id: 855698209641033729
# id: 131517399, count: 599, last_id: 847856835264749569
# id: 131517399, count: 798, last_id: 840173615131832320
# id: 131517399, count: 997, last_id: 834142545957515264
# id: 131517399, count: 1197, last_id: 822762018709053441
# id: 131517399, count: 1397, last_id: 809671604665991168
# id: 131517399, count: 1595, last_id: 801759231548555264
# id: 131517399, count: 1793, last_id: 789794906940276736
# id: 131517399, count: 1992, last_id: 780103747586367488
# id: 131517399, count: 2190, last_id: 768048994173976576
# id: 131517399, count: 2390, last_id: 757262637474390016
# id: 131517399, count: 2589, last_id: 749158201485131776
# id: 131517399, count: 2789, last_id: 743514136546578432
# id: 131517399, count: 2931, last_id: 732576570431426560
# id: 131517399, count: 2932, last_id: 0
# id: 131517399 done with 2932 status
# 985
# id: 245745762 start..
# id: 245745762, count: 200, last_id: 842305812211064832
# id: 245745762, count: 400, last_id: 801926590884118532
# id: 245745762, count: 600, last_id: 785196975192932352
# id: 245745762, count: 798, last_id: 770931836784615424
# id: 245745762, count: 997, last_id: 753890366047256576
# id: 245745762, count: 1194, last_id: 746736088333549568
# id: 245745762, count: 1393, last_id: 726541973079887873
# id: 245745762, count: 1593, last_id: 716896092433031169
# id: 245745762, count: 1791, last_id: 708976137406386176
# id: 245745762, count: 1986, last_id: 692018575494758401
# id: 245745762, count: 2186, last_id: 673237246221357056
# id: 245745762 done with 2186 status
# 986
# id: 2975603489 start..
# id: 2975603489, count: 196, last_id: 585012359984500736
# id: 2975603489 done with 196 status
# 987
# id: 2174657848 start..
# id: 2174657848, count: 200, last_id: 793023810316410880
# id: 2174657848, count: 300, last_id: 500340406144733184
# id: 2174657848 done with 300 status
# 988
# id: 131926473 start..
# id: 131926473, count: 200, last_id: 862796120606605312
# id: 131926473, count: 398, last_id: 853661490624290816
# id: 131926473, count: 598, last_id: 836709470956814336
# id: 131926473, count: 798, last_id: 812087064250482689
# id: 131926473, count: 998, last_id: 796178081400684544
# id: 131926473, count: 1198, last_id: 750641677442936832
# id: 131926473, count: 1398, last_id: 678327442872934400
# id: 131926473 done with 1398 status
# 989
# id: 854540888 start..
# id: 854540888, count: 200, last_id: 757630517072257024
# id: 854540888, count: 395, last_id: 252370864866217984
# id: 854540888 done with 395 status
# 990
# id: 1300328653 start..
# id: 1300328653, count: 199, last_id: 869503322901934080
# id: 1300328653, count: 399, last_id: 866359834115014656
# id: 1300328653, count: 599, last_id: 863336040865595392
# id: 1300328653, count: 799, last_id: 860161738842484736
# id: 1300328653, count: 998, last_id: 856486454633123841
# id: 1300328653, count: 1198, last_id: 853557079709286400
# id: 1300328653, count: 1397, last_id: 851537721571106816
# id: 1300328653, count: 1597, last_id: 849523639066255361
# id: 1300328653, count: 1795, last_id: 846254121422376960
# id: 1300328653, count: 1994, last_id: 844113431301144576
# id: 1300328653, count: 2194, last_id: 842372454525870080
# id: 1300328653, count: 2394, last_id: 839413373825650690
# id: 1300328653, count: 2473, last_id: 838061390225100810
# id: 1300328653, count: 2474, last_id: 0
# id: 1300328653 done with 2474 status
# 991
# id: 859038155101614080 start..
# id: 859038155101614080, count: 39, last_id: 860105651875401729
# id: 859038155101614080, count: 40, last_id: 0
# id: 859038155101614080 done with 40 status
# 992
# id: 118984824 start..
# id: 118984824, count: 200, last_id: 866326858517884930
# id: 118984824, count: 399, last_id: 860403452207394816
# id: 118984824, count: 599, last_id: 853646432338923520
# id: 118984824, count: 799, last_id: 847440068218310657
# id: 118984824, count: 998, last_id: 842289546666610688
# id: 118984824, count: 1198, last_id: 837278151684280321
# id: 118984824, count: 1398, last_id: 831053215626039296
# id: 118984824, count: 1598, last_id: 825002687729131520
# id: 118984824, count: 1798, last_id: 819951127504551936
# id: 118984824, count: 1996, last_id: 814154041026637824
# id: 118984824, count: 2195, last_id: 807253557086978048
# id: 118984824, count: 2395, last_id: 802868521705369600
# id: 118984824, count: 2595, last_id: 796445088230600704
# id: 118984824, count: 2795, last_id: 790098099805061120
# id: 118984824, count: 2936, last_id: 785139755730210820
# id: 118984824, count: 2937, last_id: 0
# id: 118984824 done with 2937 status
# 993
# id: 42977873 start..
# id: 42977873, count: 199, last_id: 860877732137369601
# id: 42977873, count: 384, last_id: 1984487558
# id: 42977873 done with 384 status
# 994
# id: 789825963408449536 start..
# 789825963408449536 with error
# 995
# id: 859064411948032000 start..
# id: 859064411948032000, count: 199, last_id: 870194212314255360
# id: 859064411948032000, count: 399, last_id: 866743877910360068
# id: 859064411948032000, count: 599, last_id: 862053855986692097
# id: 859064411948032000, count: 767, last_id: 859129263483752450
# id: 859064411948032000, count: 768, last_id: 0
# id: 859064411948032000 done with 768 status
# 996
# id: 97402576 start..
# id: 97402576, count: 197, last_id: 865170171777994752
# id: 97402576, count: 397, last_id: 854035865286344704
# id: 97402576, count: 596, last_id: 842425502916841472
# id: 97402576, count: 796, last_id: 835051794363469826
# id: 97402576, count: 996, last_id: 824288955860402176
# id: 97402576, count: 1195, last_id: 809036401488568320
# id: 97402576, count: 1395, last_id: 801835045103292417
# id: 97402576, count: 1595, last_id: 794256954256457733
# id: 97402576, count: 1793, last_id: 785425246077804544
# id: 97402576, count: 1991, last_id: 778496301512138752
# id: 97402576, count: 2190, last_id: 771767605761806337
# id: 97402576, count: 2389, last_id: 760890700745543680
# id: 97402576, count: 2589, last_id: 753526413077147649
# id: 97402576, count: 2789, last_id: 747471105682726912
# id: 97402576, count: 2862, last_id: 744554362006020096
# id: 97402576, count: 2863, last_id: 0
# id: 97402576 done with 2863 status
# 997
# id: 359286637 start..
# id: 359286637, count: 117, last_id: 106727935397994496
# id: 359286637 done with 117 status
# 998
# id: 862302608006017024 start..
# 862302608006017024 with error
# 999
# id: 399365200 start..
# id: 399365200, count: 200, last_id: 819911898149908482
# id: 399365200, count: 400, last_id: 775344065906872320
# id: 399365200, count: 599, last_id: 722399936638279681
# id: 399365200, count: 798, last_id: 669506048210915328
# id: 399365200 done with 798 status
# 1000
# id: 112835358 start..
# id: 112835358, count: 148, last_id: 13295475579
# id: 112835358 done with 148 status
# 1001
# id: 23769106 start..
# id: 23769106, count: 200, last_id: 870091293871022084
# id: 23769106, count: 400, last_id: 866053544608231426
# id: 23769106, count: 599, last_id: 859681190449737728
# id: 23769106, count: 797, last_id: 854826458493202432
# id: 23769106, count: 996, last_id: 851178397585862656
# id: 23769106, count: 1195, last_id: 847199764810780672
# id: 23769106, count: 1393, last_id: 841623565137018880
# id: 23769106, count: 1544, last_id: 838518087381057536
# id: 23769106, count: 1545, last_id: 0
# id: 23769106 done with 1545 status
# 1002
# id: 388299335 start..
# id: 388299335, count: 200, last_id: 859796260454322177
# id: 388299335, count: 400, last_id: 841263401565343746
# id: 388299335, count: 600, last_id: 827862193169367042
# id: 388299335, count: 800, last_id: 808618079697641472
# id: 388299335, count: 1000, last_id: 791564441661956096
# id: 388299335, count: 1200, last_id: 745163702580613120
# id: 388299335, count: 1396, last_id: 730765242117070849
# id: 388299335, count: 1594, last_id: 722873618913456129
# id: 388299335, count: 1792, last_id: 712916990869024768
# id: 388299335, count: 1992, last_id: 706443512364048384
# id: 388299335, count: 2192, last_id: 693002322356637696
# id: 388299335, count: 2392, last_id: 677775576791457792
# id: 388299335 done with 2392 status
# 1003
# id: 2202981242 start..
# id: 2202981242, count: 200, last_id: 864895753201868800
# id: 2202981242, count: 398, last_id: 853593742573531138
# id: 2202981242, count: 596, last_id: 836933019743227904
# id: 2202981242, count: 794, last_id: 825068669273268227
# id: 2202981242, count: 990, last_id: 810533454634946561
# id: 2202981242, count: 1190, last_id: 800284149751959552
# id: 2202981242, count: 1387, last_id: 778357586714329088
# id: 2202981242, count: 1587, last_id: 754598254126493696
# id: 2202981242, count: 1785, last_id: 749672408731254784
# id: 2202981242, count: 1982, last_id: 747119065706160128
# id: 2202981242, count: 2179, last_id: 622456875037102081
# id: 2202981242 done with 2179 status
# 1004
# id: 21235736 start..
# id: 21235736, count: 200, last_id: 870357409503510528
# id: 21235736, count: 400, last_id: 868467016042262529
# id: 21235736, count: 599, last_id: 863492250633949184
# id: 21235736, count: 799, last_id: 854773018974986240
# id: 21235736, count: 999, last_id: 846353225909518337
# id: 21235736, count: 1199, last_id: 839137583120723968
# id: 21235736, count: 1399, last_id: 829301290962403328
# id: 21235736, count: 1599, last_id: 823169667644751873
# id: 21235736, count: 1798, last_id: 815676946340343808
# id: 21235736, count: 1997, last_id: 803981669439049728
# id: 21235736, count: 2197, last_id: 791695213647523841
# id: 21235736, count: 2396, last_id: 778950850215550979
# id: 21235736, count: 2596, last_id: 751020958362763265
# id: 21235736, count: 2794, last_id: 746211309570527237
# id: 21235736, count: 2957, last_id: 741751750324068352
# id: 21235736, count: 2958, last_id: 0
# id: 21235736 done with 2958 status
# 1005
# id: 858023803 start..
# id: 858023803, count: 199, last_id: 852591246266822658
# id: 858023803, count: 399, last_id: 838355688858484736
# id: 858023803, count: 595, last_id: 811343045010616320
# id: 858023803, count: 793, last_id: 791281119358545921
# id: 858023803, count: 992, last_id: 781750554473234432
# id: 858023803, count: 1192, last_id: 766217447192035329
# id: 858023803, count: 1392, last_id: 749619142060347392
# id: 858023803, count: 1592, last_id: 745283649684267008
# id: 858023803, count: 1790, last_id: 735191893919866881
# id: 858023803, count: 1989, last_id: 723561130770202624
# id: 858023803, count: 2187, last_id: 701745700032401408
# id: 858023803, count: 2386, last_id: 672837688534302720
# id: 858023803 done with 2386 status
# 1006
# id: 2376645298 start..
# id: 2376645298, count: 198, last_id: 861277772043476992
# id: 2376645298, count: 398, last_id: 839469407646658560
# id: 2376645298, count: 538, last_id: 827863519521550336
# id: 2376645298, count: 539, last_id: 0
# id: 2376645298 done with 539 status
# 1007
# id: 4913754304 start..
# id: 4913754304, count: 114, last_id: 702528878900879361
# id: 4913754304, count: 115, last_id: 0
# id: 4913754304 done with 115 status
# 1008
# id: 2706402844 start..
# id: 2706402844, count: 200, last_id: 863843295776124928
# id: 2706402844, count: 400, last_id: 852851417819873284
# id: 2706402844, count: 600, last_id: 736653103903182848
# id: 2706402844, count: 800, last_id: 530853340633395201
# id: 2706402844 done with 800 status
# 1009
# id: 2749253150 start..
# id: 2749253150, count: 199, last_id: 777067240625696768
# id: 2749253150, count: 394, last_id: 751859171310567424
# id: 2749253150, count: 593, last_id: 739535375467696132
# id: 2749253150, count: 793, last_id: 595528678915858433
# id: 2749253150 done with 793 status
# 1010
# id: 20225578 start..
# id: 20225578, count: 199, last_id: 790917477148594176
# id: 20225578, count: 396, last_id: 739786419581784067
# id: 20225578, count: 595, last_id: 665632791179206656
# id: 20225578 done with 595 status
# 1011
# id: 24045870 start..
# id: 24045870, count: 199, last_id: 855563632876376065
# id: 24045870, count: 399, last_id: 818498015837229057
# id: 24045870, count: 599, last_id: 780699352062918657
# id: 24045870, count: 799, last_id: 749652639726522369
# id: 24045870, count: 997, last_id: 725602329559502848
# id: 24045870, count: 1197, last_id: 699905799980781568
# id: 24045870, count: 1397, last_id: 661948817571467264
# id: 24045870 done with 1397 status
# 1012
# id: 521246647 start..
# id: 521246647, count: 200, last_id: 801844702932766721
# id: 521246647, count: 400, last_id: 719779391744647168
# id: 521246647, count: 600, last_id: 607140110455476224
# id: 521246647 done with 600 status
# 1013
# id: 810372954 start..
# id: 810372954, count: 200, last_id: 796295366937378816
# id: 810372954, count: 400, last_id: 718168366154956800
# id: 810372954, count: 599, last_id: 686128491167911936
# id: 810372954, count: 798, last_id: 646094910886674432
# id: 810372954 done with 798 status
# 1014
# id: 2389307822 start..
# id: 2389307822, count: 111, last_id: 445840473366597632
# id: 2389307822 done with 111 status
# 1015
# id: 1912212774 start..
# id: 1912212774, count: 200, last_id: 863346343686930432
# id: 1912212774, count: 400, last_id: 847158065581473792
# id: 1912212774, count: 599, last_id: 826127821437333506
# id: 1912212774, count: 798, last_id: 807121942264315904
# id: 1912212774, count: 998, last_id: 796449354915540993
# id: 1912212774, count: 1197, last_id: 770657402152751108
# id: 1912212774, count: 1396, last_id: 746241703401623552
# id: 1912212774, count: 1595, last_id: 732466678206861312
# id: 1912212774, count: 1795, last_id: 723401343604412416
# id: 1912212774, count: 1995, last_id: 711554460322021376
# id: 1912212774, count: 2195, last_id: 701342253671968768
# id: 1912212774, count: 2393, last_id: 664887643801538560
# id: 1912212774 done with 2393 status
# 1016
# id: 20158186 start..
# id: 20158186, count: 200, last_id: 841292226865070081
# id: 20158186, count: 400, last_id: 795049007533920256
# id: 20158186, count: 600, last_id: 750318916161929216
# id: 20158186, count: 800, last_id: 716584537388617728
# id: 20158186, count: 1000, last_id: 690898546799833088
# id: 20158186, count: 1200, last_id: 666363042918178816
# id: 20158186 done with 1200 status
# 1017
# id: 19088015 start..
# id: 19088015, count: 200, last_id: 776736610029273088
# id: 19088015, count: 399, last_id: 728400263611092992
# id: 19088015, count: 599, last_id: 601656265488605184
# id: 19088015 done with 599 status
# 1018
# id: 20424362 start..
# id: 20424362, count: 199, last_id: 803004827324162052
# id: 20424362, count: 399, last_id: 775242688014811137
# id: 20424362, count: 599, last_id: 708282254959763456
# id: 20424362, count: 799, last_id: 670035349389910016
# id: 20424362 done with 799 status
# 1019
# id: 932446861 start..
# id: 932446861, count: 200, last_id: 839479536098082817
# id: 932446861, count: 400, last_id: 794152238046388229
# id: 932446861, count: 600, last_id: 751038909149241344
# id: 932446861, count: 797, last_id: 738767804560736256
# id: 932446861, count: 997, last_id: 727868729862852609
# id: 932446861, count: 1197, last_id: 706121574051659777
# id: 932446861, count: 1396, last_id: 611632360463990784
# id: 932446861 done with 1396 status
# 1020
# id: 2764245625 start..
# id: 2764245625, count: 197, last_id: 781618758582431745
# id: 2764245625, count: 397, last_id: 612550314202427392
# id: 2764245625 done with 397 status
# 1021
# id: 43927999 start..
# id: 43927999, count: 102, last_id: 548362823030808576
# id: 43927999 done with 102 status
# 1022
# id: 327335701 start..
# id: 327335701, count: 107, last_id: 87532534107344896
# id: 327335701 done with 107 status
# 1023
# id: 864748270651887616 start..
# 864748270651887616 with error
# 1024
# id: 216516145 start..
# id: 216516145, count: 200, last_id: 799530054472568833
# id: 216516145, count: 400, last_id: 730117781224599552
# id: 216516145, count: 600, last_id: 674996042300026881
# id: 216516145 done with 600 status
# 1025
# id: 34244239 start..
# id: 34244239, count: 199, last_id: 868794437140402176
# id: 34244239, count: 399, last_id: 861954894705684480
# id: 34244239, count: 599, last_id: 856975094446514176
# id: 34244239, count: 799, last_id: 849232109906657280
# id: 34244239, count: 999, last_id: 844135485094158337
# id: 34244239, count: 1199, last_id: 837255401485832196
# id: 34244239, count: 1399, last_id: 829313747726528512
# id: 34244239, count: 1599, last_id: 822030575951286276
# id: 34244239, count: 1799, last_id: 811299145143250945
# id: 34244239, count: 1998, last_id: 807266333679304704
# id: 34244239, count: 2198, last_id: 802576159603126272
# id: 34244239, count: 2397, last_id: 795597743502819333
# id: 34244239, count: 2597, last_id: 789219219166617600
# id: 34244239, count: 2797, last_id: 780763554349719552
# id: 34244239, count: 2836, last_id: 778855854317637632
# id: 34244239, count: 2837, last_id: 0
# id: 34244239 done with 2837 status
# 1026
# id: 28568666 start..
# id: 28568666, count: 200, last_id: 598866712986017792
# id: 28568666 done with 200 status
# 1027
# id: 40336185 start..
# id: 40336185, count: 200, last_id: 765171356531032064
# id: 40336185, count: 399, last_id: 673097161366757377
# id: 40336185 done with 399 status
# 1028
# id: 2880093051 start..
# id: 2880093051, count: 140, last_id: 536164241020309505
# id: 2880093051 done with 140 status
# 1029
# id: 1731554581 start..
# id: 1731554581, count: 200, last_id: 859002787245568000
# id: 1731554581, count: 400, last_id: 832277804368744448
# id: 1731554581, count: 600, last_id: 796440933185134592
# id: 1731554581, count: 799, last_id: 774169387624374272
# id: 1731554581, count: 999, last_id: 754580920829677568
# id: 1731554581, count: 1195, last_id: 742002905637588993
# id: 1731554581, count: 1395, last_id: 723495534204465152
# id: 1731554581, count: 1595, last_id: 687562229751902208
# id: 1731554581, count: 1793, last_id: 611437580983386112
# id: 1731554581 done with 1793 status
# 1030
# id: 241279770 start..
# id: 241279770, count: 200, last_id: 595219210151862272
# id: 241279770 done with 200 status
# 1031
# id: 870010567 start..
# id: 870010567, count: 200, last_id: 670965555772399616
# id: 870010567 done with 200 status
# 1032
# id: 860896517737119744 start..
# 860896517737119744 with error
# 1033
# id: 131957012 start..
# id: 131957012, count: 200, last_id: 777159935801040897
# id: 131957012, count: 400, last_id: 449667692791070721
# id: 131957012 done with 400 status
# 1034
# id: 20995648 start..
# id: 20995648, count: 200, last_id: 870612341473333248
# id: 20995648, count: 400, last_id: 869287118262161409
# id: 20995648, count: 598, last_id: 865538753808314368
# id: 20995648, count: 797, last_id: 860505038002806784
# id: 20995648, count: 996, last_id: 856186979331002369
# id: 20995648, count: 1196, last_id: 851074186714001408
# id: 20995648, count: 1396, last_id: 846018609604366336
# id: 20995648, count: 1596, last_id: 841324326313971712
# id: 20995648, count: 1796, last_id: 835102953316966401
# id: 20995648, count: 1937, last_id: 832345971984056321
# id: 20995648, count: 1938, last_id: 0
# id: 20995648 done with 1938 status
# 1035
# id: 855455848377798656 start..
# 855455848377798656 with error
# 1036
# id: 568625156 start..
# id: 568625156, count: 200, last_id: 852591154998759424
# id: 568625156, count: 400, last_id: 831990494855065608
# id: 568625156, count: 600, last_id: 818011388077604864
# id: 568625156, count: 800, last_id: 794850504396378113
# id: 568625156, count: 1000, last_id: 778919670283923456
# id: 568625156, count: 1199, last_id: 767162291888480256
# id: 568625156, count: 1398, last_id: 757719555225559040
# id: 568625156, count: 1598, last_id: 747547804957028352
# id: 568625156, count: 1798, last_id: 728208570416803840
# id: 568625156, count: 1998, last_id: 717065660619235328
# id: 568625156, count: 2198, last_id: 702163439238647808
# id: 568625156, count: 2398, last_id: 688072525939650561
# id: 568625156, count: 2598, last_id: 661224942156009472
# id: 568625156 done with 2598 status
# 1037
# id: 121070777 start..
# id: 121070777, count: 43, last_id: 10225726238
# id: 121070777 done with 43 status
# 1038
# id: 2818248860 start..
# id: 2818248860, count: 200, last_id: 753373915368529920
# id: 2818248860, count: 399, last_id: 597767501183868929
# id: 2818248860 done with 399 status
# 1039
# id: 862412232797368320 start..
# 862412232797368320 with error
# 1040
# id: 2839705834 start..
# id: 2839705834, count: 196, last_id: 774201608959889408
# id: 2839705834, count: 396, last_id: 698062748387831808
# id: 2839705834, count: 596, last_id: 611057308290936832
# id: 2839705834 done with 596 status
# 1041
# id: 22159580 start..
# id: 22159580, count: 199, last_id: 858611939647389698
# id: 22159580, count: 398, last_id: 834480471379673088
# id: 22159580, count: 596, last_id: 801441473438904320
# id: 22159580, count: 794, last_id: 781750093154136066
# id: 22159580, count: 993, last_id: 746138263262535682
# id: 22159580, count: 1191, last_id: 725677321127137280
# id: 22159580, count: 1390, last_id: 718380709648445440
# id: 22159580, count: 1590, last_id: 709730897902362624
# id: 22159580, count: 1790, last_id: 697372740215386112
# id: 22159580, count: 1988, last_id: 689944439964450817
# id: 22159580, count: 2186, last_id: 672387513277915136
# id: 22159580 done with 2186 status
# 1042
# id: 4453006828 start..
# id: 4453006828, count: 199, last_id: 854668028264493058
# id: 4453006828, count: 399, last_id: 831936891595395072
# id: 4453006828, count: 599, last_id: 803668505690259456
# id: 4453006828, count: 799, last_id: 795590206690906112
# id: 4453006828, count: 999, last_id: 761263423833436160
# id: 4453006828, count: 1129, last_id: 675452075216519171
# id: 4453006828 done with 1129 status
# 1043
# id: 9226332 start..
# id: 9226332, count: 183, last_id: 545708718034534401
# id: 9226332 done with 183 status
# 1044
# id: 23452834 start..
# id: 23452834, count: 200, last_id: 844501232358166528
# id: 23452834, count: 399, last_id: 760728341615878144
# id: 23452834, count: 598, last_id: 757224610307989504
# id: 23452834, count: 798, last_id: 753633623895572480
# id: 23452834, count: 997, last_id: 749858729235972096
# id: 23452834, count: 1195, last_id: 742655130546405377
# id: 23452834, count: 1393, last_id: 739529045864534016
# id: 23452834, count: 1593, last_id: 736152098526638080
# id: 23452834, count: 1792, last_id: 733991434278318080
# id: 23452834, count: 1992, last_id: 730725788862042112
# id: 23452834, count: 2187, last_id: 728171651226062848
# id: 23452834, count: 2386, last_id: 725203252912992256
# id: 23452834, count: 2586, last_id: 711213433442672641
# id: 23452834, count: 2786, last_id: 665682980770197504
# id: 23452834 done with 2786 status
# 1045
# id: 859506792698695680 start..
# id: 859506792698695680, count: 195, last_id: 860786997228691457
# id: 859506792698695680, count: 251, last_id: 859517652531908608
# id: 859506792698695680, count: 252, last_id: 0
# id: 859506792698695680 done with 252 status
# 1046
# id: 218789670 start..
# id: 218789670, count: 200, last_id: 838087963368120323
# id: 218789670, count: 400, last_id: 763771875080171520
# id: 218789670, count: 596, last_id: 723925692627488768
# id: 218789670, count: 796, last_id: 642385090350329856
# id: 218789670 done with 796 status
# 1047
# id: 40444755 start..
# id: 40444755, count: 200, last_id: 862185295676133376
# id: 40444755, count: 400, last_id: 852862371714519041
# id: 40444755, count: 600, last_id: 839386843321888770
# id: 40444755, count: 800, last_id: 828635452638892032
# id: 40444755, count: 1000, last_id: 811890218722791425
# id: 40444755, count: 1197, last_id: 799970890054176768
# id: 40444755, count: 1397, last_id: 786841245515706368
# id: 40444755, count: 1595, last_id: 779639656757469184
# id: 40444755, count: 1795, last_id: 707676577992204288
# id: 40444755, count: 1995, last_id: 620020269630029825
# id: 40444755 done with 1995 status
# 1048
# id: 124170781 start..
# id: 124170781, count: 200, last_id: 866278420816244738
# id: 124170781, count: 400, last_id: 857139832262406144
# id: 124170781, count: 600, last_id: 835386828417019904
# id: 124170781, count: 800, last_id: 824695830137499649
# id: 124170781, count: 1000, last_id: 784412635404075008
# id: 124170781, count: 1199, last_id: 741710903859646464
# id: 124170781, count: 1399, last_id: 722891976517951490
# id: 124170781, count: 1599, last_id: 698135995439587328
# id: 124170781, count: 1799, last_id: 661959607997374465
# id: 124170781 done with 1799 status
# 1049
# id: 855899514087112704 start..
# id: 855899514087112704, count: 144, last_id: 859805585142894592
# id: 855899514087112704, count: 145, last_id: 0
# id: 855899514087112704 done with 145 status
# 1050
# id: 185794012 start..
# id: 185794012, count: 200, last_id: 869227052238503937
# id: 185794012, count: 400, last_id: 859654003126403072
# id: 185794012, count: 600, last_id: 840299505371213824
# id: 185794012, count: 799, last_id: 825717366143217665
# id: 185794012, count: 998, last_id: 806562328363859972
# id: 185794012, count: 1198, last_id: 788092168049221632
# id: 185794012, count: 1397, last_id: 750773181863096320
# id: 185794012, count: 1596, last_id: 672182272741781504
# id: 185794012 done with 1596 status
# 1051
# id: 20132840 start..
# id: 20132840, count: 200, last_id: 826434037925474305
# id: 20132840, count: 399, last_id: 738821981936705536
# id: 20132840, count: 599, last_id: 728322903738068992
# id: 20132840, count: 799, last_id: 705056657387229184
# id: 20132840, count: 997, last_id: 689507181285236736
# id: 20132840, count: 1197, last_id: 612235635412332544
# id: 20132840 done with 1197 status
# 1052
# id: 209029473 start..
# id: 209029473, count: 200, last_id: 853204621795479552
# id: 209029473, count: 400, last_id: 823570819389550592
# id: 209029473, count: 600, last_id: 790067671224246272
# id: 209029473, count: 800, last_id: 764089855399776256
# id: 209029473, count: 1000, last_id: 747086717199523845
# id: 209029473, count: 1198, last_id: 733931100104478721
# id: 209029473, count: 1397, last_id: 710067449979342848
# id: 209029473, count: 1597, last_id: 687719855622098944
# id: 209029473, count: 1795, last_id: 669233894584164353
# id: 209029473 done with 1795 status
# 1053
# id: 175786071 start..
# id: 175786071, count: 200, last_id: 865493763761647620
# id: 175786071, count: 399, last_id: 853721932675592192
# id: 175786071, count: 596, last_id: 826083068184231937
# id: 175786071, count: 794, last_id: 799524314236207104
# id: 175786071, count: 993, last_id: 785056487626465280
# id: 175786071, count: 1192, last_id: 772558128755908609
# id: 175786071, count: 1390, last_id: 759878633552916480
# id: 175786071, count: 1588, last_id: 748674474321530880
# id: 175786071, count: 1783, last_id: 735043720295395328
# id: 175786071, count: 1976, last_id: 718523269838684160
# id: 175786071, count: 2167, last_id: 672018045032886272
# id: 175786071 done with 2167 status
# 1054
# id: 1531710163 start..
# id: 1531710163, count: 200, last_id: 849659073159208962
# id: 1531710163, count: 400, last_id: 818140369770651648
# id: 1531710163, count: 600, last_id: 789547939647655936
# id: 1531710163, count: 800, last_id: 753481434594217984
# id: 1531710163, count: 999, last_id: 727538722384797697
# id: 1531710163, count: 1198, last_id: 715316633800216578
# id: 1531710163, count: 1398, last_id: 703847605986422784
# id: 1531710163, count: 1598, last_id: 682634220343312384
# id: 1531710163 done with 1598 status
# 1055
# id: 55219630 start..
# id: 55219630, count: 200, last_id: 856946149625868291
# id: 55219630, count: 400, last_id: 840540779995115520
# id: 55219630, count: 600, last_id: 823828503363813376
# id: 55219630, count: 799, last_id: 799034343230439424
# id: 55219630, count: 999, last_id: 770577291571257345
# id: 55219630, count: 1198, last_id: 739857196939399169
# id: 55219630, count: 1396, last_id: 717806820484579330
# id: 55219630, count: 1595, last_id: 699561648940457986
# id: 55219630, count: 1793, last_id: 683048634691235840
# id: 55219630, count: 1899, last_id: 672929458781843456
# id: 55219630 done with 1899 status
# 1056
# id: 217148014 start..
# id: 217148014, count: 200, last_id: 776694015680974848
# id: 217148014, count: 400, last_id: 719970238129786881
# id: 217148014, count: 598, last_id: 669510218062143488
# id: 217148014 done with 598 status
# 1057
# id: 2757416225 start..
# id: 2757416225, count: 200, last_id: 828851487199596544
# id: 2757416225, count: 398, last_id: 755073722428555265
# id: 2757416225, count: 598, last_id: 706932472395735040
# id: 2757416225, count: 771, last_id: 508677209079697408
# id: 2757416225 done with 771 status
# 1058
# id: 854293219278020608 start..
# id: 854293219278020608, count: 199, last_id: 854621214366674944
# id: 854293219278020608, count: 216, last_id: 854386919777685504
# id: 854293219278020608, count: 217, last_id: 0
# id: 854293219278020608 done with 217 status
# 1059
# id: 541898068 start..
# 541898068 with error
# 1060
# id: 948015937 start..
# id: 948015937, count: 199, last_id: 871007552296935424
# id: 948015937, count: 398, last_id: 869660074515550213
# id: 948015937, count: 595, last_id: 868750019221966852
# id: 948015937, count: 795, last_id: 866008404199919616
# id: 948015937, count: 995, last_id: 863854064198668288
# id: 948015937, count: 1195, last_id: 860796398211665920
# id: 948015937, count: 1393, last_id: 857699509631102976
# id: 948015937, count: 1592, last_id: 854774863470501888
# id: 948015937, count: 1792, last_id: 852075747615416320
# id: 948015937, count: 1969, last_id: 847149540549505025
# id: 948015937, count: 1970, last_id: 0
# id: 948015937 done with 1970 status
# 1061
# id: 1699862954 start..
# id: 1699862954, count: 197, last_id: 759146794588700672
# id: 1699862954, count: 389, last_id: 684504758758043649
# id: 1699862954, count: 584, last_id: 634114945874063360
# id: 1699862954 done with 584 status
# 1062
# id: 52412027 start..
# id: 52412027, count: 197, last_id: 818419633803956227
# id: 52412027, count: 393, last_id: 751446613277671424
# id: 52412027, count: 592, last_id: 706167819210248192
# id: 52412027, count: 791, last_id: 649853352591945728
# id: 52412027 done with 791 status
# 1063
# id: 71996772 start..
# id: 71996772, count: 197, last_id: 779572238316077056
# id: 71996772, count: 396, last_id: 597411025823084545
# id: 71996772 done with 396 status
# 1064
# id: 857980058375475200 start..
# id: 857980058375475200, count: 69, last_id: 858622005045858304
# id: 857980058375475200, count: 70, last_id: 0
# id: 857980058375475200 done with 70 status
# 1065
# id: 144929619 start..
# id: 144929619, count: 200, last_id: 839476341355479040
# id: 144929619, count: 400, last_id: 804371702083944448
# id: 144929619, count: 600, last_id: 783957564379705345
# id: 144929619, count: 800, last_id: 763631857661517824
# id: 144929619, count: 1000, last_id: 752228871165140992
# id: 144929619, count: 1200, last_id: 743828019870064640
# id: 144929619, count: 1400, last_id: 727940362938007553
# id: 144929619, count: 1600, last_id: 713627224851759105
# id: 144929619, count: 1800, last_id: 695937008276017154
# id: 144929619, count: 2000, last_id: 676168946886815744
# id: 144929619 done with 2000 status
# 1066
# id: 14260148 start..
# id: 14260148, count: 200, last_id: 807863450630311936
# id: 14260148, count: 400, last_id: 741598422462042112
# id: 14260148, count: 599, last_id: 678194949033230336
# id: 14260148 done with 599 status
# 1067
# id: 2319613536 start..
# id: 2319613536, count: 200, last_id: 859708351466360832
# id: 2319613536, count: 400, last_id: 844865830613483522
# id: 2319613536, count: 600, last_id: 833264250906869760
# id: 2319613536, count: 799, last_id: 822795668544700417
# id: 2319613536, count: 999, last_id: 816161646397820928
# id: 2319613536, count: 1199, last_id: 804619201281409024
# id: 2319613536, count: 1399, last_id: 793779896153767936
# id: 2319613536, count: 1599, last_id: 785936807615668228
# id: 2319613536, count: 1793, last_id: 773926646579601408
# id: 2319613536, count: 1992, last_id: 749187957224013824
# id: 2319613536, count: 2191, last_id: 722404257908072449
# id: 2319613536, count: 2390, last_id: 704692722804854785
# id: 2319613536, count: 2589, last_id: 674163890159251456
# id: 2319613536 done with 2589 status
# 1068
# id: 2653613168 start..
# id: 2653613168, count: 199, last_id: 808469827065147392
# id: 2653613168, count: 399, last_id: 741008146584502272
# id: 2653613168, count: 599, last_id: 698486867696734208
# id: 2653613168, count: 799, last_id: 652423281602109440
# id: 2653613168 done with 799 status
# 1069
# id: 854056084226658304 start..
# id: 854056084226658304, count: 200, last_id: 869794240376844289
# id: 854056084226658304, count: 400, last_id: 857663805731594240
# id: 854056084226658304, count: 478, last_id: 854059056436260864
# id: 854056084226658304, count: 479, last_id: 0
# id: 854056084226658304 done with 479 status
# 1070
# id: 1072226575 start..
# id: 1072226575, count: 200, last_id: 847580122882428929
# id: 1072226575, count: 400, last_id: 813524191060303872
# id: 1072226575, count: 599, last_id: 775744849693868032
# id: 1072226575, count: 799, last_id: 748927533677240321
# id: 1072226575, count: 999, last_id: 728650978367524864
# id: 1072226575, count: 1198, last_id: 707565850677649409
# id: 1072226575, count: 1397, last_id: 676910124607397889
# id: 1072226575 done with 1397 status
# 1071
# id: 2517208410 start..
# id: 2517208410, count: 192, last_id: 871956999910686720
# id: 2517208410, count: 193, last_id: 0
# id: 2517208410 done with 193 status
# 1072
# id: 421203325 start..
# id: 421203325, count: 200, last_id: 854600498414047232
# id: 421203325, count: 399, last_id: 806893581663436801
# id: 421203325, count: 598, last_id: 770659282119454720
# id: 421203325, count: 796, last_id: 728577162245226496
# id: 421203325, count: 996, last_id: 708074913085714433
# id: 421203325, count: 1195, last_id: 670641742392262657
# id: 421203325 done with 1195 status
# 1073
# id: 114704539 start..
# id: 114704539, count: 200, last_id: 793904677293322244
# id: 114704539, count: 400, last_id: 587972748913278976
# id: 114704539 done with 400 status
# 1074
# id: 2476759038 start..
# id: 2476759038, count: 200, last_id: 805090485073309697
# id: 2476759038, count: 294, last_id: 462937516195446785
# id: 2476759038 done with 294 status
# 1075
# id: 1129434462 start..
# id: 1129434462, count: 200, last_id: 826176264922861570
# id: 1129434462, count: 399, last_id: 778688816055857152
# id: 1129434462, count: 599, last_id: 726163553682620416
# id: 1129434462, count: 796, last_id: 690319629365985280
# id: 1129434462, count: 994, last_id: 595007734233300993
# id: 1129434462 done with 994 status
# 1076
# id: 4010545737 start..
# id: 4010545737, count: 199, last_id: 725034487353057282
# id: 4010545737, count: 371, last_id: 656880154887737344
# id: 4010545737 done with 371 status
# 1077
# id: 930599510 start..
# id: 930599510, count: 199, last_id: 781543533605953536
# id: 930599510, count: 398, last_id: 568157089824186368
# id: 930599510 done with 398 status
# 1078
# id: 368570637 start..
# id: 368570637, count: 200, last_id: 637768653790937089
# id: 368570637 done with 200 status
# 1079
# id: 385306338 start..
# id: 385306338, count: 200, last_id: 837277429685157888
# id: 385306338, count: 400, last_id: 818078676176740355
# id: 385306338, count: 600, last_id: 791263280790695937
# id: 385306338, count: 800, last_id: 755418070387089408
# id: 385306338, count: 999, last_id: 699171968482992128
# id: 385306338, count: 1196, last_id: 596294511023792129
# id: 385306338 done with 1196 status
# 1080
# id: 1235025320 start..
# id: 1235025320, count: 195, last_id: 850279371562770432
# id: 1235025320, count: 393, last_id: 777921729033302016
# id: 1235025320, count: 589, last_id: 729708079835680768
# id: 1235025320, count: 780, last_id: 690215532981809153
# id: 1235025320, count: 980, last_id: 652200423491813376
# id: 1235025320 done with 980 status
# 1081
# id: 36664451 start..
# id: 36664451, count: 199, last_id: 750222909830995968
# id: 36664451, count: 398, last_id: 651512059356684288
# id: 36664451 done with 398 status
# 1082
# id: 773088432847544320 start..
# id: 773088432847544320, count: 200, last_id: 869919161530683393
# id: 773088432847544320, count: 400, last_id: 865170755700625408
# id: 773088432847544320, count: 600, last_id: 860188972768792576
# id: 773088432847544320, count: 800, last_id: 805108588737871872
# id: 773088432847544320, count: 916, last_id: 773093945492594688
# id: 773088432847544320, count: 917, last_id: 0
# id: 773088432847544320 done with 917 status
# 1083
# id: 93860818 start..
# id: 93860818, count: 199, last_id: 869301889812365313
# id: 93860818, count: 398, last_id: 864913542629261312
# id: 93860818, count: 596, last_id: 860200939331956736
# id: 93860818, count: 796, last_id: 856057725352128512
# id: 93860818, count: 996, last_id: 850713897002774528
# id: 93860818, count: 1196, last_id: 843108938883239937
# id: 93860818, count: 1394, last_id: 837356508367241217
# id: 93860818, count: 1594, last_id: 834383426824331264
# id: 93860818, count: 1794, last_id: 825378474890317828
# id: 93860818, count: 1994, last_id: 817769377185533953
# id: 93860818, count: 2194, last_id: 808353267965198336
# id: 93860818, count: 2394, last_id: 801826372968730625
# id: 93860818, count: 2594, last_id: 795990535345475584
# id: 93860818, count: 2645, last_id: 794966290024763393
# id: 93860818, count: 2646, last_id: 0
# id: 93860818 done with 2646 status
# 1084
# id: 502115759 start..
# id: 502115759, count: 200, last_id: 829683389888339968
# id: 502115759, count: 400, last_id: 784740317530558464
# id: 502115759, count: 598, last_id: 725584170517430272
# id: 502115759, count: 797, last_id: 663731305008521216
# id: 502115759 done with 797 status
# 1085
# id: 28306725 start..
# id: 28306725, count: 199, last_id: 850076390238105600
# ...
# id: 2483456906, count: 198, last_id: 791039664807407616
# id: 2483456906, count: 398, last_id: 719615612755042304
# id: 2483456906, count: 598, last_id: 659700878488768512
# id: 2483456906 done with 598 status
# 1416
# id: 93880122 start..
# id: 93880122, count: 200, last_id: 841231718958956544
# id: 93880122, count: 400, last_id: 826463170210455554
# id: 93880122, count: 600, last_id: 796684612764372992
# id: 93880122, count: 800, last_id: 755768545653293056
# id: 93880122, count: 1000, last_id: 741860265969352704
# id: 93880122, count: 1200, last_id: 718418938514710528
# id: 93880122, count: 1400, last_id: 606429088732069888
# id: 93880122 done with 1400 status
# 1417
# id: 32965648 start..
# id: 32965648, count: 200, last_id: 823566080354426880
# id: 32965648, count: 400, last_id: 780719356011548672
# id: 32965648, count: 600, last_id: 750346740436443136
# id: 32965648, count: 800, last_id: 740883636573048832
# id: 32965648, count: 999, last_id: 732911054993424384
# id: 32965648, count: 1199, last_id: 715536026949795840
# id: 32965648, count: 1397, last_id: 703663206712082432
# id: 32965648, count: 1596, last_id: 675638538398994432
# id: 32965648 done with 1596 status
# 1418
# id: 24467456 start..
# id: 24467456, count: 199, last_id: 867038437844684800
# id: 24467456, count: 399, last_id: 859333240917811200
# id: 24467456, count: 599, last_id: 847817382777286656
# id: 24467456, count: 799, last_id: 841612547883192320
# id: 24467456, count: 998, last_id: 834909615146033153
# id: 24467456, count: 1198, last_id: 828612268019576832
# id: 24467456, count: 1398, last_id: 818640870937337856
# id: 24467456, count: 1597, last_id: 808329850742341632
# id: 24467456, count: 1797, last_id: 801450164212928517
# id: 24467456, count: 1997, last_id: 795367775707471873
# id: 24467456, count: 2197, last_id: 788646364360110080
# id: 24467456, count: 2397, last_id: 781478650537467904
# id: 24467456, count: 2562, last_id: 776717366772269056
# id: 24467456, count: 2563, last_id: 0
# id: 24467456 done with 2563 status
# 1419
# id: 25091518 start..
# id: 25091518, count: 200, last_id: 848136170374656001
# id: 25091518, count: 400, last_id: 825466116789170177
# id: 25091518, count: 599, last_id: 801412983742140416
# id: 25091518, count: 799, last_id: 782333457884151808
# id: 25091518, count: 998, last_id: 766260036414894081
# id: 25091518, count: 1196, last_id: 743554034741706752
# id: 25091518, count: 1394, last_id: 732181953458405380
# id: 25091518, count: 1591, last_id: 716179844334292992
# id: 25091518, count: 1790, last_id: 705095300072001536
# id: 25091518, count: 1988, last_id: 682157662398738432
# id: 25091518 done with 1988 status
# 1420
# id: 2834640796 start..
# id: 2834640796, count: 32, last_id: 563613836587315200
# id: 2834640796 done with 32 status
# 1421
# id: 4758642640 start..
# id: 4758642640, count: 199, last_id: 861231427324719104
# id: 4758642640, count: 296, last_id: 685959991535251456
# id: 4758642640, count: 297, last_id: 0
# id: 4758642640 done with 297 status
# 1422
# id: 193302048 start..
# 193302048 with error
# 1423
# id: 258834854 start..
# id: 258834854, count: 200, last_id: 512597087549411328
# id: 258834854 done with 200 status
# 1424
# id: 4213022061 start..
# id: 4213022061, count: 149, last_id: 666763131604107265
# id: 4213022061 done with 149 status
# 1425
# id: 391162297 start..
# id: 391162297, count: 200, last_id: 858294877406322689
# id: 391162297, count: 400, last_id: 822870710389526530
# id: 391162297, count: 600, last_id: 768827899319291904
# id: 391162297, count: 799, last_id: 732678505465581568
# id: 391162297, count: 999, last_id: 673196841379479552
# id: 391162297 done with 999 status
# 1426
# id: 1978270322 start..
# id: 1978270322, count: 200, last_id: 867997345949995009
# id: 1978270322, count: 400, last_id: 862249748069318656
# id: 1978270322, count: 600, last_id: 857631387200999425
# id: 1978270322, count: 800, last_id: 845679409281601536
# id: 1978270322, count: 1000, last_id: 834302630113452032
# id: 1978270322, count: 1200, last_id: 819879890296172544
# id: 1978270322, count: 1399, last_id: 796758137885835265
# id: 1978270322, count: 1598, last_id: 775944842882846721
# id: 1978270322, count: 1796, last_id: 755748984258428929
# id: 1978270322, count: 1996, last_id: 750802830424965121
# id: 1978270322, count: 2195, last_id: 745717254256472064
# id: 1978270322, count: 2394, last_id: 740954935420936192
# id: 1978270322, count: 2594, last_id: 734828187646058496
# id: 1978270322, count: 2792, last_id: 726678666009255936
# id: 1978270322, count: 2855, last_id: 723480438422036480
# id: 1978270322, count: 2856, last_id: 0
# id: 1978270322 done with 2856 status
# 1427
# id: 580947925 start..
# id: 580947925, count: 200, last_id: 845778864009809920
# id: 580947925, count: 399, last_id: 819269517687844864
# id: 580947925, count: 598, last_id: 788656258882609152
# id: 580947925, count: 797, last_id: 756102238393827328
# id: 580947925, count: 994, last_id: 739879442017857536
# id: 580947925, count: 1193, last_id: 721993422102466560
# id: 580947925, count: 1390, last_id: 703890414944780289
# id: 580947925, count: 1587, last_id: 684536583538782208
# id: 580947925, count: 1786, last_id: 673631389003194368
# id: 580947925 done with 1786 status
# 1428
# id: 2561204678 start..
# id: 2561204678, count: 51, last_id: 476707681643036672
# id: 2561204678 done with 51 status
# 1429
# id: 3244940967 start..
# id: 3244940967, count: 200, last_id: 856422598158282752
# id: 3244940967, count: 400, last_id: 843749954082553856
# id: 3244940967, count: 600, last_id: 824177421213634562
# id: 3244940967, count: 800, last_id: 804438870041460736
# id: 3244940967, count: 1000, last_id: 783632372734500864
# id: 3244940967, count: 1200, last_id: 741024653439860736
# id: 3244940967, count: 1240, last_id: 597864236057030656
# id: 3244940967 done with 1240 status
# 1430
# id: 331178901 start..
# id: 331178901, count: 199, last_id: 869839956826619904
# id: 331178901, count: 397, last_id: 866693105080250368
# id: 331178901, count: 597, last_id: 862787942984675332
# id: 331178901, count: 795, last_id: 858750817242886147
# id: 331178901, count: 995, last_id: 854682977044967426
# id: 331178901, count: 1194, last_id: 850015236023345152
# id: 331178901, count: 1394, last_id: 845772449874612224
# id: 331178901, count: 1593, last_id: 842161730566389760
# id: 331178901, count: 1792, last_id: 838527237913784320
# id: 331178901, count: 1991, last_id: 834550169152659456
# id: 331178901, count: 2078, last_id: 832730662499184640
# id: 331178901, count: 2079, last_id: 0
# id: 331178901 done with 2079 status
# 1431
# id: 16667402 start..
# id: 16667402, count: 199, last_id: 868510072988733440
# id: 16667402, count: 398, last_id: 864742516444323840
# id: 16667402, count: 598, last_id: 857916876231520256
# id: 16667402, count: 798, last_id: 852859907011473408
# id: 16667402, count: 998, last_id: 847578857385463809
# id: 16667402, count: 1195, last_id: 841757978537648128
# id: 16667402, count: 1392, last_id: 834463529780596742
# id: 16667402, count: 1591, last_id: 826950551262859265
# id: 16667402, count: 1789, last_id: 821476730422652929
# id: 16667402, count: 1989, last_id: 814136756010422272
# id: 16667402, count: 2189, last_id: 807576459246260225
# id: 16667402, count: 2388, last_id: 801878314063278080
# id: 16667402, count: 2588, last_id: 797940615833128960
# id: 16667402, count: 2788, last_id: 793818338321395712
# id: 16667402, count: 2789, last_id: 0
# id: 16667402 done with 2789 status
# 1432
# id: 110405901 start..
# id: 110405901, count: 0, last_id: 0
# id: 110405901 done with 0 status
# 1433
# id: 858747670562734080 start..
# 858747670562734080 with error
# 1434
# id: 478839833 start..
# id: 478839833, count: 200, last_id: 868155858156433412
# id: 478839833, count: 400, last_id: 860616716895879171
# id: 478839833, count: 599, last_id: 856849960792453120
# id: 478839833, count: 799, last_id: 854450104627060739
# id: 478839833, count: 997, last_id: 852219414669926409
# id: 478839833, count: 1197, last_id: 848818625104547840
# id: 478839833, count: 1397, last_id: 844113159766065153
# id: 478839833, count: 1596, last_id: 840110215840190464
# id: 478839833, count: 1796, last_id: 837687480245706752
# id: 478839833, count: 1995, last_id: 834384402926931969
# id: 478839833, count: 2195, last_id: 823460774567968769
# id: 478839833, count: 2395, last_id: 816410437004693504
# id: 478839833, count: 2595, last_id: 802083126315024384
# id: 478839833, count: 2795, last_id: 796458678492758020
# id: 478839833, count: 2858, last_id: 795274887359332352
# id: 478839833, count: 2859, last_id: 0
# id: 478839833 done with 2859 status
# 1435
# id: 115887294 start..
# id: 115887294, count: 200, last_id: 860303495571922944
# id: 115887294, count: 399, last_id: 847187667330748416
# id: 115887294, count: 598, last_id: 834443715972300802
# id: 115887294, count: 797, last_id: 821815306796548096
# id: 115887294, count: 997, last_id: 806528007779352576
# id: 115887294, count: 1197, last_id: 793152855939178496
# id: 115887294, count: 1396, last_id: 780290365400252416
# id: 115887294, count: 1596, last_id: 766344190850719744
# id: 115887294, count: 1794, last_id: 754653811831111680
# id: 115887294, count: 1993, last_id: 741940352031035392
# id: 115887294, count: 2192, last_id: 725825930640396288
# id: 115887294, count: 2391, last_id: 713117628093579264
# id: 115887294, count: 2591, last_id: 702223755725168640
# id: 115887294, count: 2790, last_id: 689068550796013569
# id: 115887294, count: 2824, last_id: 687373878784557057
# id: 115887294, count: 2825, last_id: 0
# id: 115887294 done with 2825 status
# 1436
# id: 121762421 start..
# id: 121762421, count: 200, last_id: 866572731936067585
# id: 121762421, count: 400, last_id: 859696786449076225
# id: 121762421, count: 600, last_id: 851763850752008192
# id: 121762421, count: 798, last_id: 843894931957669889
# id: 121762421, count: 998, last_id: 838709359861465088
# id: 121762421, count: 1198, last_id: 833811257983692801
# id: 121762421, count: 1397, last_id: 827148200461099008
# id: 121762421, count: 1597, last_id: 819196327078875138
# id: 121762421, count: 1797, last_id: 809391461879922689
# id: 121762421, count: 1997, last_id: 803942156599697415
# id: 121762421, count: 2197, last_id: 798540750552203264
# id: 121762421, count: 2397, last_id: 791253084882276352
# id: 121762421, count: 2596, last_id: 787044712448454656
# id: 121762421, count: 2796, last_id: 780431335940845568
# id: 121762421, count: 2863, last_id: 778612843918884864
# id: 121762421, count: 2864, last_id: 0
# id: 121762421 done with 2864 status
# 1437
# id: 15157283 start..
# id: 15157283, count: 200, last_id: 870734824256024577
# id: 15157283, count: 400, last_id: 868116438489468929
# id: 15157283, count: 600, last_id: 859313914038947841
# id: 15157283, count: 800, last_id: 849912433368064000
# id: 15157283, count: 1000, last_id: 844621281643384833
# id: 15157283, count: 1200, last_id: 841561602100989953
# id: 15157283, count: 1400, last_id: 839393658969419776
# id: 15157283, count: 1600, last_id: 836973374605824000
# id: 15157283, count: 1800, last_id: 831473502511329282
# id: 15157283, count: 2000, last_id: 828934954662891520
# id: 15157283, count: 2200, last_id: 823934102986428416
# id: 15157283, count: 2400, last_id: 821328581016121344
# id: 15157283, count: 2600, last_id: 818574577248911364
# id: 15157283, count: 2800, last_id: 811687380289724416
# id: 15157283, count: 2924, last_id: 809431400944377856
# id: 15157283, count: 2925, last_id: 0
# id: 15157283 done with 2925 status
# 1438
# id: 830374908219764736 start..
# id: 830374908219764736, count: 118, last_id: 830384317025099777
# id: 830374908219764736, count: 119, last_id: 0
# id: 830374908219764736 done with 119 status
# 1439
# id: 187553649 start..
# id: 187553649, count: 60, last_id: 521726917935132672
# id: 187553649 done with 60 status
# 1440
# id: 20226550 start..
# id: 20226550, count: 200, last_id: 858068578893008896
# id: 20226550, count: 400, last_id: 844145770198695936
# id: 20226550, count: 600, last_id: 831312074248691720
# id: 20226550, count: 799, last_id: 796277821039591424
# id: 20226550, count: 999, last_id: 747003478585769984
# id: 20226550, count: 1197, last_id: 743405078481113089
# id: 20226550, count: 1396, last_id: 664394139899940864
# id: 20226550 done with 1396 status
# 1441
# id: 2196660992 start..
# id: 2196660992, count: 199, last_id: 576471146981376000
# id: 2196660992 done with 199 status
# 1442
# id: 954543176 start..
# id: 954543176, count: 152, last_id: 530371748907466753
# id: 954543176 done with 152 status
# 1443
# id: 21406457 start..
# id: 21406457, count: 200, last_id: 850234823142629376
# id: 21406457, count: 400, last_id: 820548425582256128
# id: 21406457, count: 600, last_id: 784261228617097216
# id: 21406457, count: 800, last_id: 751450135981424640
# id: 21406457, count: 1000, last_id: 708995342193315841
# id: 21406457, count: 1197, last_id: 678320411952611328
# id: 21406457 done with 1197 status
# 1444
# id: 143405324 start..
# id: 143405324, count: 200, last_id: 855151289143111681
# id: 143405324, count: 400, last_id: 803490440762839040
# id: 143405324, count: 600, last_id: 737554278491918336
# id: 143405324, count: 800, last_id: 703918837482332160
# id: 143405324, count: 999, last_id: 596575359199539200
# id: 143405324 done with 999 status
# 1445
# id: 2786796467 start..
# id: 2786796467, count: 197, last_id: 593878098648633344
# id: 2786796467 done with 197 status
# 1446
# id: 856200666976595968 start..
# 856200666976595968 with error
# 1447
# id: 71777646 start..
# id: 71777646, count: 200, last_id: 843811929504301057
# id: 71777646, count: 400, last_id: 809092203951878144
# id: 71777646, count: 600, last_id: 789464358858395648
# id: 71777646, count: 799, last_id: 764588014609850368
# id: 71777646, count: 997, last_id: 733540395217342464
# id: 71777646, count: 1197, last_id: 712292948390633473
# id: 71777646, count: 1395, last_id: 701710459360190464
# id: 71777646, count: 1595, last_id: 674905709964877825
# id: 71777646 done with 1595 status
# 1448
# id: 1655569938 start..
# id: 1655569938, count: 200, last_id: 857538559644925953
# id: 1655569938, count: 400, last_id: 828558078266208257
# id: 1655569938, count: 600, last_id: 808751762505142273
# id: 1655569938, count: 800, last_id: 786937639547068416
# id: 1655569938, count: 999, last_id: 756042176698707968
# id: 1655569938, count: 1197, last_id: 745586299550171136
# id: 1655569938, count: 1397, last_id: 742463308675047424
# id: 1655569938, count: 1597, last_id: 738812266871726081
# id: 1655569938, count: 1797, last_id: 719803953869889536
# id: 1655569938, count: 1997, last_id: 705313274586382336
# id: 1655569938, count: 2196, last_id: 695336220558172160
# id: 1655569938, count: 2395, last_id: 672878319084392449
# id: 1655569938 done with 2395 status
# 1449
# id: 19672313 start..
# id: 19672313, count: 0, last_id: 0
# id: 19672313 done with 0 status
# 1450
# id: 1354610803 start..
# id: 1354610803, count: 199, last_id: 868359976363929600
# id: 1354610803, count: 399, last_id: 863634181615759360
# id: 1354610803, count: 599, last_id: 857689339794526208
# id: 1354610803, count: 798, last_id: 849352908885897216
# id: 1354610803, count: 998, last_id: 840306427864465412
# id: 1354610803, count: 1197, last_id: 834701281390428160
# id: 1354610803, count: 1395, last_id: 827643659378102276
# id: 1354610803, count: 1593, last_id: 819546812331806722
# id: 1354610803, count: 1793, last_id: 812380543295819776
# id: 1354610803, count: 1993, last_id: 800717042324275200
# id: 1354610803, count: 2191, last_id: 793919022567985153
# id: 1354610803, count: 2390, last_id: 784724452839985152
# id: 1354610803, count: 2586, last_id: 765316947655417856
# id: 1354610803, count: 2689, last_id: 762751534040018944
# id: 1354610803, count: 2690, last_id: 0
# id: 1354610803 done with 2690 status
# 1451
# id: 2911584543 start..
# id: 2911584543, count: 199, last_id: 869994400688033792
# id: 2911584543, count: 398, last_id: 865592764519657472
# id: 2911584543, count: 597, last_id: 861240014969212928
# id: 2911584543, count: 796, last_id: 844539544263430151
# id: 2911584543, count: 996, last_id: 718124704884781057
# id: 2911584543, count: 1196, last_id: 615847051167973376
# id: 2911584543 done with 1196 status
# 1452
# id: 35795737 start..
# id: 35795737, count: 200, last_id: 722047340400369669
# id: 35795737, count: 400, last_id: 364988303176499200
# id: 35795737 done with 400 status
# 1453
# id: 109845429 start..
# id: 109845429, count: 200, last_id: 855118537509269505
# id: 109845429, count: 238, last_id: 828770931707408385
# id: 109845429, count: 239, last_id: 0
# id: 109845429 done with 239 status

# %%
len(list_id_2017_SP)
# Out:
# 1455

# %%
dataset_17sp = []
with open('crawler_2017.txt', 'r') as file:
    for line in file:
        dataset_17sp.append(json.loads(line))

# %%
len(dataset_17sp)
# Out:
# 1479676

# %%
csv_out = open('tweets_2017sp.csv', mode='w', newline='') #opens csv file
writer = csv.writer(csv_out) #create the csv writer object
 
fields = ['created_at', 'text', 'screen_name', 'followers', 'friends', 'rt', 'fav','mentioned', 'quoted', 'reweet'] #field names
writer.writerow(fields) #writes field

for line in dataset_17sp:
    
    #writes a row and gets the fields from the json object
    #screen_name and followers/friends are found on the second level hence two get methods
    writer.writerow([line.get('created_at'),
                     line.get('text').encode('unicode_escape'), #unicode escape to fix emoji issue
                     line.get('user').get('screen_name'),
                     line.get('user').get('followers_count'),
                     line.get('user').get('friends_count'),
                     line.get('retweet_count'),
                     line.get('favorite_count'),
                     line.get('entities').get('user_mentions')[0].get('name') if line.get('entities').get('user_mentions') != [] else None,
                     line.get('quoted_status').get('user').get('name', 'None') if line.get('quoted_status') != None else None,
                
                     line.get('retweeted_status').get('user').get('name', 'None') if line.get('retweeted_status') != None else None
                    ])
csv_out.close()

# %% [markdown]
# ## Second Degree of MP Followers

# %%
def Get_degree(screenname = '442069868'):
    friend_list = [u.id for u in api.GetFollowers(screen_name = screenname)]
    print(friend_list)
    friend_degree = []
    for ids in friend_list:
        temp_friend_list = [u.id for u in api.GetFollowers(user_id=ids)]
        k =  len(temp_friend_list)
        print(k)
        friend_degree.append(k)
    avg_k = sum(friend_degree)/len(friend_list)
    max_k = max(friend_degree)
    print(screenname, avg_k, max_k)

# %%
def Get_degree(userid = 1603153040):
    record = []
    try:
        friend_list = api.GetFollowers(user_id = userid)
    except:
        deadlist.append(userid)
        print(str(userid) + ' with error')
        return 
   
    print('{} get {} friends'.format(userid, len(friend_list)))
    friend_degree = []
    follower_degree = []
    for users in friend_list:

        followers =  users._json.get('followers_count')
        friends =  users._json.get('friends_count')
        friend_degree.append(friends)
        follower_degree.append(followers)
    avg_fr = sum(friend_degree)/len(friend_list)
    max_fr = max(friend_degree)
    min_fr = min(friend_degree)
    avg_fo = sum(follower_degree)/len(friend_list)
    max_fo = max(follower_degree)
    min_fo = min(follower_degree)
    var_fr = np.var(friend_degree)
    var_fo = np.var(follower_degree)
    record = [userid, avg_fr, max_fr, min_fr, var_fr, avg_fo, max_fo, min_fo, var_fo]
    print('{} get {} friends done'.format(userid, len(friend_list)))
    with open('neighbor_information.csv', 'a') as myfile:
        myfile.write('{}\n'.format(','.join(map(str,record))))
    return record

# %%
# list_id_2015_SP
count = 511
# dataset_15sp = []

# %%
new_list_id = list_id_2015_SP

# %%
for _id in new_list_id[count:-1]:
    print(_id, count)
    Get_degree(userid = _id)
    count = count +1
#         wr.writerow(Get_degree(userid = id))
# Out:
# 192935794 511

# %%
import pygame
pygame.mixer.init()
print("克啥 跑完了")
track = pygame.mixer.music.load("03 Lucky.mp3")
pygame.mixer.music.play()

# %%
new_list_id[49]
# Out:
# 236953412

# %%
Get_degree(userid = 236953412)

# %%
 with open('neighbor_information', 'w') as myfile:
        wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
        wr.writerow(lalala)

# %%
lalala = [1,2,3,4,5]

# %%
deadlist
# Out:
# [192935794]

# %%
new_list_id[511]
# Out:
# 192935794
