# %%
import pandas as pd
import numpy as np
import re
import collections

# %%
df_all_data = pd.read_csv('tweets_2017sp.csv')

# %%
df_all_data.head(50)
# Out:
#                         created_at  \
# 0   Thu Jun 08 05:52:27 +0000 2017
# 1   Wed Jun 07 20:27:13 +0000 2017
# 2   Wed Jun 07 20:27:08 +0000 2017
# 3   Wed Jun 07 17:28:22 +0000 2017
# 4   Wed Jun 07 15:34:18 +0000 2017
# 5   Wed Jun 07 10:07:05 +0000 2017
# 6   Wed Jun 07 08:00:50 +0000 2017
# 7   Tue Jun 06 18:37:49 +0000 2017
# 8   Tue Jun 06 10:15:25 +0000 2017
# 9   Tue Jun 06 07:06:08 +0000 2017
# 10  Mon Jun 05 21:26:11 +0000 2017
# 11  Mon Jun 05 17:42:51 +0000 2017
# 12  Mon Jun 05 16:29:33 +0000 2017
# 13  Mon Jun 05 16:21:51 +0000 2017
# 14  Mon Jun 05 15:12:14 +0000 2017
# 15  Mon Jun 05 13:22:37 +0000 2017
# 16  Mon Jun 05 13:05:06 +0000 2017
# 17  Mon Jun 05 11:40:47 +0000 2017
# 18  Mon Jun 05 06:43:03 +0000 2017
# 19  Sat Jun 03 18:19:30 +0000 2017
# 20  Sat Jun 03 18:11:20 +0000 2017
# 21  Sat Jun 03 17:10:28 +0000 2017
# 22  Sat Jun 03 12:28:06 +0000 2017
# 23  Fri Jun 02 20:48:43 +0000 2017
# 24  Fri Jun 02 19:49:45 +0000 2017
# 25  Thu Jun 01 22:51:57 +0000 2017
# 26  Thu Jun 01 18:54:22 +0000 2017
# 27  Thu Jun 01 12:28:35 +0000 2017
# 28  Thu Jun 01 12:19:18 +0000 2017
# 29  Wed May 31 22:13:38 +0000 2017
# 30  Wed May 31 21:08:04 +0000 2017
# 31  Wed May 31 20:24:43 +0000 2017
# 32  Wed May 31 19:07:42 +0000 2017
# 33  Wed May 31 14:27:10 +0000 2017
# 34  Wed May 31 14:07:15 +0000 2017
# 35  Tue May 30 22:35:21 +0000 2017
# 36  Tue May 30 20:53:54 +0000 2017
# 37  Tue May 30 20:52:27 +0000 2017
# 38  Tue May 30 20:24:22 +0000 2017
# 39  Tue May 30 20:22:49 +0000 2017
# 40  Tue May 30 20:14:21 +0000 2017
# 41  Tue May 30 20:08:15 +0000 2017
# 42  Tue May 30 14:03:51 +0000 2017
# 43  Tue May 30 11:54:05 +0000 2017
# 44  Tue May 30 11:37:30 +0000 2017
# 45  Tue May 30 11:27:23 +0000 2017
# 46  Tue May 30 11:20:18 +0000 2017
# 47  Tue May 30 11:15:52 +0000 2017
# 48  Tue May 30 11:13:14 +0000 2017
# 49  Mon May 29 18:54:11 +0000 2017
#
#                                                  text screen_name  followers  \
# 0   b'Today is polling day. Use your vote to today...    SKinnock      15315
# 1   b'RT @WelshLabour: End the Tory cuts. \\nInves...    SKinnock      15315
# 2   b'Great day on the #LabourDoorstep in Cymmer, ...    SKinnock      15315
# 3   b'RT @AfanLodge: Great to see these guys today...    SKinnock      15315
# 4   b'RT @UKLabour: Labour is standing up for pens...    SKinnock      15315
# 47  b"And we're in the ring... https://t.co/vnto9L...    SKinnock      15315
# 48  b'Lots of excitement as @RossKemp arrives at t...    SKinnock      15315
# 49  b'Great to be out knocking doors in a somewhat...    SKinnock      15315
#
#     friends    rt  fav             mentioned        quoted  \
# 0      1239    14   30                   NaN           NaN
# 1      1239    45    0          Welsh Labour           NaN
# 2      1239    13   16                   NaN           NaN
# 3      1239     4    0            Afan Lodge           NaN
# 4      1239   331    0      The Labour Party           NaN
# 5      1239    22   43                   NaN           NaN
# 6      1239  1381    0      The Labour Party           NaN
# 7      1239     5   18       Taste Brasserie           NaN
# 8      1239    23    0            Adam Brown           NaN
# 9      1239     8   12                   NaN           NaN
# 10     1239     6    5            NPT Online           NaN
# 11     1239    12   11                   NaN           NaN
# 12     1239    11   28                   NaN           NaN
# 13     1239     6    5                   NaN           NaN
# 14     1239    29   27          David Hanson           NaN
# 15     1239    14   17                   NaN           NaN
# 16     1239     3   23                   NaN           NaN
# 17     1239     7    0             TCW Jones           NaN
# 18     1239    25   39                   NaN           NaN
# 19     1239    50  109                   NaN           NaN
# 20     1239     3    0        susanne renkes           NaN
# 21     1239     4    0           Gemma Parry           NaN
# 22     1239     7    7                   NaN           NaN
# 23     1239     3    0           Chwarae Teg           NaN
# 24     1239     8    4                   NaN           NaN
# 25     1239     3    0           Chris James           NaN
# 26     1239     6    3                   NaN           NaN
# 27     1239     7    9                   NaN   Chris James
# 28     1239    31    0    Welsh Labour Press           NaN
# 29     1239     8    0  Aberavon School Boys           NaN
# 30     1239    68    0             Ross Kemp           NaN
# 31     1239     8    7             SafeLives           NaN
# 32     1239    10   16                   NaN           NaN
# 33     1239    10   46                   NaN           NaN
# 34     1239     2    2                   NaN  Marc Antolin
# 35     1239    21   30      Andrew RT Davies           NaN
# 36     1239    61    0          Welsh Labour           NaN
# 37     1239     0   23          Morgan Jones           NaN
# 38     1239     4    0  Paul Ridd Foundation           NaN
# 39     1239    27    0          Welsh Labour           NaN
# 40     1239    89    0          Welsh Labour           NaN
# 41     1239     6    4                   NaN           NaN
# 42     1239    37   34                   NaN           NaN
# 43     1239    11   13             Ross Kemp           NaN
# 44     1239     7    9             Ross Kemp           NaN
# 45     1239     8    4             Ross Kemp           NaN
# 46     1239    11   13             Ross Kemp           NaN
# 47     1239     6    5                   NaN           NaN
# 48     1239    10   11             Ross Kemp           NaN
# 49     1239     8    7                   NaN           NaN
#
#                   reweet
# 0                    NaN
# 1           Welsh Labour
# 2                    NaN
# 3             Afan Lodge
# 4       The Labour Party
# 5                    NaN
# 6       The Labour Party
# 7                    NaN
# 8             Adam Brown
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17             TCW Jones
# 18                   NaN
# 19                   NaN
# 20        susanne renkes
# 21           Gemma Parry
# 22                   NaN
# 23           Chwarae Teg
# 24                   NaN
# 25           Chris James
# 26                   NaN
# 27                   NaN
# 28    Welsh Labour Press
# 29  Aberavon School Boys
# 30             Ross Kemp
# 31                   NaN
# 32                   NaN
# 33                   NaN
# 34                   NaN
# 35                   NaN
# 36          Welsh Labour
# 37                   NaN
# 38  Paul Ridd Foundation
# 39          Welsh Labour
# 40          Welsh Labour
# 41                   NaN
# 42                   NaN
# 43                   NaN
# 44                   NaN
# 45                   NaN
# 46                   NaN
# 47                   NaN
# 48                   NaN
# 49                   NaN

# %%
len(df_all_data)
# Out:
# 1479676

# %%
df_all_data = df_all_data.drop_duplicates()

# %%
len(df_all_data)
# Out:
# 1468405

# %%
df_all_data.to_csv('cleaned_2017_SP_candidates.csv')

# %%
df_cleaned = pd.read_csv('cleaned_2017_SP_candidates.csv')

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0                      created_at  \
# 0           0  Thu Jun 08 05:52:27 +0000 2017
# 1           1  Wed Jun 07 20:27:13 +0000 2017
# 2           2  Wed Jun 07 20:27:08 +0000 2017
# 3           3  Wed Jun 07 17:28:22 +0000 2017
# 4           4  Wed Jun 07 15:34:18 +0000 2017
#
#                                                 text screen_name  followers  \
# 0  b'Today is polling day. Use your vote to today...    SKinnock      15315
# 1  b'RT @WelshLabour: End the Tory cuts. \\nInves...    SKinnock      15315
# 2  b'Great day on the #LabourDoorstep in Cymmer, ...    SKinnock      15315
# 3  b'RT @AfanLodge: Great to see these guys today...    SKinnock      15315
# 4  b'RT @UKLabour: Labour is standing up for pens...    SKinnock      15315
#
#    friends   rt  fav         mentioned quoted            reweet
# 0     1239   14   30               NaN    NaN               NaN
# 1     1239   45    0      Welsh Labour    NaN      Welsh Labour
# 2     1239   13   16               NaN    NaN               NaN
# 3     1239    4    0        Afan Lodge    NaN        Afan Lodge
# 4     1239  331    0  The Labour Party    NaN  The Labour Party

# %%
df_cleaned = df_cleaned.drop(['Unnamed: 0'], axis=1)

# %%
len(df_cleaned.screen_name.unique())
# Out:
# 1315

# %%
len(df_cleaned)
# Out:
# 1468405

# %% [markdown]
# ## @ Retweet features

# %%
feature_columns = ['twitter_username', 'tweets_count', 'followers', 'friends', 'retweet','favrotes', 'mentioned', 'quoted', 'reweet', 'mentioned%', 'quoted%', 'reweet%']
df_features = pd.DataFrame(columns=feature_columns)

# %%
tmps = []
# count = 0
tweets_count = 1
followers = 0
friends = 0
retweet = 0
favrotes= 0
mentioned = 0
quoted = 0
reweet = 0
m_ratio = 0
q_ratio = 0
r_ratio = 0

# %%
previous_name = "213zsj"

for index, row in df_cleaned.iterrows():
    if previous_name != row.screen_name:
        m_ratio = mentioned/tweets_count
        q_ratio = quoted/tweets_count
        r_ratio = reweet/tweets_count
        tmps.append([previous_name,tweets_count,followers,friends,retweet,favrotes,mentioned,quoted,reweet,m_ratio,q_ratio,r_ratio])
        previous_name = row.screen_name
        tweets_count = 1
        followers = row.followers
        friends = row.friends
        retweet = row.rt
        favrotes = row.fav
        mentioned = 0
        quoted = 0
        reweet = 0
        if pd.isnull(row.mentioned) is True:
            mentioned += 1
        if pd.isnull(row.quoted) is True:
            quoted += 1
        if pd.isnull(row.reweet) is True:
            reweet += 1
    else:
        tweets_count += 1
        retweet += row.rt
        favrotes += row.fav
        if pd.isnull(row.mentioned) is True:
            mentioned += 1
        if pd.isnull(row.quoted) is True:
            quoted += 1
        if pd.isnull(row.reweet) is True:
            reweet += 1

#     count = count +1
#     if count > 10000:
#         break

# %%
feature_columns = ['twitter_username', 'tweets_count', 'followers', 'friends', 'retweet','favrotes', 'mentioned', 'quoted', 'reweet', 'mentioned%', 'quoted%', 'reweet%']
# 96         740    2465    1717    0.248072  0.826349  0.575595
# 97         278    1140     664    0.218553  0.896226  0.522013
# 98         169     794     475    0.201190  0.945238  0.565476
# 99         276    1750     437    0.154969  0.982594  0.245368
# 100        474    2085    1713    0.216044  0.950319  0.780766
#
# [100 rows x 12 columns]

# %%
len(df_features)
# Out:
# 1315

# %%
df_features = df_features.drop_duplicates(subset='twitter_username', keep="last")
len(df_features)
# Out:
# 1314

# %%
len(df_features.twitter_username.unique())
# Out:
# 1314

# %% [markdown]
# ## SENTIMENT

# %%
import nltk
import sentiment_mod as s
# Out:
# 10662

# %%
len(df_data4pre)
# Out:
# 1468405

# %%
count = 0 
for index, tweet in df_data4pre["text"].iteritems():
    sentiment_value, confidence = s.sentiment(tweet)
    print(tweet, sentiment_value, confidence)
    count += 1
    if confidence*100 >= 80:
        output = open("twitter-out.txt","a")
        output.write(sentiment_value)
        output.write('\n')
        output.close()
    if count > 10:
        break
# Out:
# b'today is polling day. use your vote to today to change our country for the better. votelabour today. aberavon\\u2026  neg 1.0
# b'rt AT_USER end the tory cuts. \\ninvest in infrastructure &amp; skills. \\nstop the tories trampling over wales.\\n\\nhttps:// st\\u2026 neg 1.0
# b'great day on the labourdoorstep in cymmer, cwmavon &amp; croeserw. we even persisted through the rain! ready for polli\\u2026  neg 1.0
# b'rt AT_USER great to see these guys today out on the campaign trail thanks for calling in for a fuel stop AT_USER  pos 0.6
# b'rt AT_USER labour is standing up for pensioners. see what we will do and tell people to votelabour \\u2193  neg 1.0
# b'for an mp who will standupforsteel votelabour in aberavon tomorrow. ge2017  neg 1.0
# b'rt AT_USER we can make history tomorrow, are you with us? rt this and let your friends know \\u2193 votelabour forthemany  neg 1.0
# b'time for a nice cuppa and welsh cake in AT_USER after a long day on labourdoorstep in port talbot and bri\\u2026  neg 1.0
# b"rt AT_USER all steelworkers must vote labour if they want a future.. tories don't care AT_USER AT_USER saveoursteel \\u2026 neg 0.6
# b'lets stop the tory steamroller running through aberavon votelabour on thursday ge2017  neg 1.0
# b"really enjoyed tonight's AT_USER facebook live debate ge2017\\nyou can watch it back here: AT_USER AT_USER ge17 pos 1.0

# %%
sentiment_tmp = []
tweets_count = 1
postive = 0
negative = 0
previous_name = "213zsj"
sum_sentiment = 0
for index, row in df_data4pre.iterrows():
    if previous_name != row.screen_name:
        postive_r = postive/tweets_count
        negative_r = negative/tweets_count
        sentiment_tmp.append([previous_name,tweets_count,postive,negative,sum_sentiment,postive_r,negative_r])
        previous_name = row.screen_name
        sum_sentiment = 0
        tweets_count = 1
        postive = 0
        negative = 0
        tweet = row.text
        sentiment_value, confidence = s.sentiment(tweet)
        if sentiment_value == "pos":
            postive += 1
            sum_sentiment = sum_sentiment + confidence
        else:
            negative +=1
            sum_sentiment = sum_sentiment - confidence
    else:
        tweets_count += 1
        tweet = row.text
        sentiment_value, confidence = s.sentiment(tweet)
        if sentiment_value == "pos":
            postive += 1
            sum_sentiment = sum_sentiment + confidence
        else:
            negative +=1
            sum_sentiment = sum_sentiment - confidence

# %%
import pygame
pygame.mixer.init()
print("克啥 跑完了")
track = pygame.mixer.music.load("03 Lucky.mp3")
pygame.mixer.music.play()
# Out:
# 克啥 跑完了

# %%
len(sentiment_tmp)
# Out:
# 1316

# %%
len(df_features)
# Out:
# 1314

# %%
sentiment_columns = ['twitter_username', 'tweets_count', 'postive', 'negative', 'sum_sentiment','postive_r', 'negative_r']
df_sentiment_features = pd.DataFrame(data=sentiment_tmp, columns=sentiment_columns)

# %%
df_sentiment_features = df_sentiment_features.drop([0])

# %%
df_sentiment_features.head(100)
# Out:
#     twitter_username  tweets_count  postive  negative  sum_sentiment  \
# 1           SKinnock          2617      927      1690         -720.4
# 2              CenLD          2798      942      1856         -831.6
# 3         sadievidal            22       12        10            1.6
# 4      GutoAberconwy           335      122       213          -85.6
# 5    Emily4Aberconwy           698      264       434         -158.2
# 6     isobeldavidson           335      104       231         -124.6
# 7    Grace_E_OKeeffe           183       62       121          -52.0
# 8     OrrVinegoldLab            11        8         3            5.2
# 9      callumjodwyer          2593      713      1880        -1094.4
# 10    RossThomson_MP          2943     1176      1767         -547.0
# 11           wilsjen           843      243       600         -325.2
# 12   AirdrieShottsLP           250       65       185         -113.8
# 13     LeoDochertyUK           375      141       234          -86.2
# 14       alanhilliar             1        1         0            1.0
# 15      Gary_Puffett          2903      946      1957         -923.2
# 16      JohnFisher_1           284       96       188          -87.0
# 17         ablibdems             1        0         1           -0.8
# 18      morton_wendy           496      199       297          -89.2
# 19      JaneBrophyLD          2347      766      1581         -755.6
# 20    AndrewHWestern           696      234       462         -215.6
# 21     lauraknightly           147       53        94          -39.4
# 22        MarkTamiMP           891      308       583         -237.2
# 23   CllrJamesDawson          2372      723      1649         -841.4
# 24   KateSmithLibDem             2        1         1            0.0
# 25    Campbell4Angus           132       24       108          -77.4
# 26    Kirstene4Angus           355      136       219          -81.0
# 27      CliveSneddon           338       85       253         -160.4
# 28     marygwengriff           782      236       546         -283.0
# 29     AlanReidAandB            11        3         8           -4.4
# 30         LabourASD           543      139       404         -257.2
# ..               ...           ...      ...       ...            ...
# 71         annietrev          2757     1112      1645         -476.8
# 72     VoteCarolineB           105       34        71          -36.2
# 73          John2Win          1178      445       733         -277.4
# 74      rushanaraali          1537      591       946         -309.8
# 75     WilliamPHDyer           535      126       409         -267.6
# 76       JohannaBoal           133       43        90          -45.0
# 77      grahamstuart           553      222       331          -96.4
# 78        Bayliss4BB           213       36       177         -130.4
# 79          jpkemp94           757      252       505         -237.6
# 80       HuwMerriman           865      370       495         -123.6
# 81       StefBorella          2163      615      1548         -885.6
# 82     DavidEvennett           604      217       387         -166.8
# 83          SimRey14          2351      667      1684         -949.0
# 84        AllanBrame           472      149       323         -159.2
# 85    frankfieldteam           573      193       380         -170.6
# 86      ColinGreenLD           830      245       585         -316.2
# 87      JackDromeyMP          2149      947      1202         -222.2
# 88          Jerry4MP           151       49       102          -48.2
# 89      RogerGodsiff           133       25       108          -79.8
# 90      Reena_Ranger           258       97       161          -55.4
# 91    PhilBennionMEP             1        0         1           -0.6
# 92       LiamByrneMP          2305      821      1484         -582.0
# 93       ar_browning            17        7        10           -3.0
# 94         leedargue          2287      747      1540         -737.4
# 95    ShabanaMahmood           821      292       529         -211.2
# 96   RichardBurdenMP          2983     1020      1963         -882.4
# 97          rogerbhx          1272      334       938         -569.6
# 98             ch4pb           840      368       472          -91.0
# 99         khalid4PB          1781      588      1193         -561.6
# 100     steve_mccabe          2194      668      1526         -793.4
#
#      postive_r  negative_r
# 1     0.354222    0.645778
# 2     0.336669    0.663331
# 3     0.545455    0.454545
# 4     0.364179    0.635821
# 5     0.378223    0.621777
# 6     0.310448    0.689552
# 7     0.338798    0.661202
# 8     0.727273    0.272727
# 9     0.274971    0.725029
# 10    0.399592    0.600408
# 11    0.288256    0.711744
# 12    0.260000    0.740000
# 13    0.376000    0.624000
# 14    1.000000    0.000000
# 15    0.325870    0.674130
# 16    0.338028    0.661972
# 17    0.000000    1.000000
# 18    0.401210    0.598790
# 19    0.326374    0.673626
# 20    0.336207    0.663793
# 21    0.360544    0.639456
# 22    0.345679    0.654321
# 23    0.304806    0.695194
# 24    0.500000    0.500000
# 25    0.181818    0.818182
# 26    0.383099    0.616901
# 27    0.251479    0.748521
# 28    0.301790    0.698210
# 29    0.272727    0.727273
# 30    0.255985    0.744015
# ..         ...         ...
# 71    0.403337    0.596663
# 72    0.323810    0.676190
# 73    0.377759    0.622241
# 74    0.384515    0.615485
# 75    0.235514    0.764486
# 76    0.323308    0.676692
# 77    0.401447    0.598553
# 78    0.169014    0.830986
# 79    0.332893    0.667107
# 80    0.427746    0.572254
# 81    0.284327    0.715673
# 82    0.359272    0.640728
# 83    0.283709    0.716291
# 84    0.315678    0.684322
# 85    0.336824    0.663176
# 86    0.295181    0.704819
# 87    0.440670    0.559330
# 88    0.324503    0.675497
# 89    0.187970    0.812030
# 90    0.375969    0.624031
# 91    0.000000    1.000000
# 92    0.356182    0.643818
# 93    0.411765    0.588235
# 94    0.326629    0.673371
# 95    0.355664    0.644336
# 96    0.341938    0.658062
# 97    0.262579    0.737421
# 98    0.438095    0.561905
# 99    0.330152    0.669848
# 100   0.304467    0.695533
#
# [100 rows x 7 columns]

# %%
df_sentiment_features.to_csv('17sentiment_features.csv')

# %% [markdown]
# ## Preprocessing before sentiment analysis

# %%
from nltk.corpus import stopwords
import preprocessor as p
p.set_options(p.OPT.URL, p.OPT.EMOJI)

# %%
###Preprocess tweets
def processTweet(tweet):
    # process the tweets

    #Convert to lower case
    tweet = tweet.lower()
    #Convert www.* or https?://* to URL
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet)
    #Convert @username to AT_USER
    tweet = re.sub('@[^\s]+','AT_USER',tweet)
    #Remove additional white spaces
    tweet = re.sub('[\s]+', ' ', tweet)
    #Replace #word with word
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
    #trim
    tweet = tweet.strip('\'"')
    return tweet

# %%
df_data4pre = df_cleaned

# %%
df_data4pre['text'] = df_data4pre.text.apply(lambda x: p.clean(x))

# %%
df_data4pre['text'].head()
# Out:
# 0    b'Today is polling day. Use your vote to today...
# 1    b'RT @WelshLabour: End the Tory cuts. \\nInves...
# 2    b'Great day on the #LabourDoorstep in Cymmer, ...
# 3    b'RT @AfanLodge: Great to see these guys today...
# 4    b'RT @UKLabour: Labour is standing up for pens...
# Name: text, dtype: object

# %%
df_data4pre['text'] = df_data4pre.text.apply(lambda x: processTweet(x))

# %%
df_data4pre = df_data4pre.reset_index(drop=True)

# %%
df_data4pre.head()
# Out:
#                        created_at  \
# 0  Thu Jun 08 05:52:27 +0000 2017
# 1  Wed Jun 07 20:27:13 +0000 2017
# 2  Wed Jun 07 20:27:08 +0000 2017
# 3  Wed Jun 07 17:28:22 +0000 2017
# 4  Wed Jun 07 15:34:18 +0000 2017
#
#                                                 text screen_name  followers  \
# 0  b'today is polling day. use your vote to today...    SKinnock      15315
# 1  b'rt AT_USER end the tory cuts. \\ninvest in i...    SKinnock      15315
# 2  b'great day on the labourdoorstep in cymmer, c...    SKinnock      15315
# 3  b'rt AT_USER great to see these guys today out...    SKinnock      15315
# 4  b'rt AT_USER labour is standing up for pension...    SKinnock      15315
#
#    friends   rt  fav         mentioned quoted            reweet
# 0     1239   14   30               NaN    NaN               NaN
# 1     1239   45    0      Welsh Labour    NaN      Welsh Labour
# 2     1239   13   16               NaN    NaN               NaN
# 3     1239    4    0        Afan Lodge    NaN        Afan Lodge
# 4     1239  331    0  The Labour Party    NaN  The Labour Party

# %%
len(df_data4pre)
# Out:
# 1468405

# %% [markdown]
# ## Word Counts

# %%
###get stopword list
def getStopWordList(stopWordListFileName):
    #read the stopwords file and build a list
    stopWords = []
    stopWords.append('AT_USER')
    stopWords.append('URL')

    fp = open(stopWordListFileName, 'r')
    line = fp.readline()
    while line:
        word = line.strip()
        stopWords.append(word)
        line = fp.readline()
    fp.close()
    return stopWords

stopWords = []

# st = open('stopword_large.txt', 'r')
stopWords = getStopWordList('stopword_large.txt')
    
def replaceTwoOrMore(s):
    #look for 2 or more repetitions of character and replace with the character itself
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL)
    return pattern.sub(r"\1\1", s)
#end

# %%
# df_data4pre['text'][0]
df_data4pre.head()
# Out:
#                        created_at  \
# 0  Thu Jun 08 05:52:27 +0000 2017
# 1  Wed Jun 07 20:27:13 +0000 2017
# 2  Wed Jun 07 20:27:08 +0000 2017
# 3  Wed Jun 07 17:28:22 +0000 2017
# 4  Wed Jun 07 15:34:18 +0000 2017
#
#                                                 text screen_name  followers  \
# 0  b'today is polling day. use your vote to today...    SKinnock      15315
# 1  b'rt AT_USER end the tory cuts. \\ninvest in i...    SKinnock      15315
# 2  b'great day on the labourdoorstep in cymmer, c...    SKinnock      15315
# 3  b'rt AT_USER great to see these guys today out...    SKinnock      15315
# 4  b'rt AT_USER labour is standing up for pension...    SKinnock      15315
#
#    friends   rt  fav         mentioned quoted            reweet
# 0     1239   14   30               NaN    NaN               NaN
# 1     1239   45    0      Welsh Labour    NaN      Welsh Labour
# 2     1239   13   16               NaN    NaN               NaN
# 3     1239    4    0        Afan Lodge    NaN        Afan Lodge
# 4     1239  331    0  The Labour Party    NaN  The Labour Party

# %%
featureVector = []
frequency = {}
for i in range(len(df_data4pre['text'])):
    words = df_data4pre['text'][i].split()
    for w in words:
        #replace two or more with two occurrences
        w = replaceTwoOrMore(w)
        #strip punctuation
        w = w.strip('\'"?,.')
        #check if the word stats with an alphabet
        val = re.search(r"^[a-zA-Z][a-zA-Z0-9]*$", w)
        #ignore if it is a stop word
        w = w.lower()
        if(w in stopWords or val is None):
            continue
        else:
            featureVector.append(w)
            count = frequency.get(w,0)
            frequency[w] = count + 1
            
frequency_list = frequency.keys()

# %%
High_frenquency_words = collections.Counter(frequency)
descend_High_frenquency_words = collections.OrderedDict(sorted(High_frenquency_words.items(), key=lambda t: t[0]))

# %%
result = sorted(High_frenquency_words.items() , key=lambda t : t[1] , reverse=True)

# %%
result
# Out:
# [('labour', 65058),
#  ('today', 64547),
#  ('great', 60549),
#  ('brexit', 54987),
#  ('people', 54648),
#  ('vote', 50160),
#  ('support', 41368),
#  ('eu', 40189),
#  ('good', 40003),
#  ('uk', 39414),
#  ('day', 32015),
#  ('time', 30181),
#  ('local', 28447),
#  ('campaign', 28403),
#  ('work', 27367),
#  ('mp', 26173),
#  ('tory', 25632),
#  ('party', 25551),
#  ('nhs', 25307),
#  ('tories', 24840),
#  ('make', 23766),
#  ('election', 22560),
#  ('back', 22476),
#  ('government', 20854),
#  ('theresa', 20180),
#  ('morning', 19825),
#  ('news', 19371),
#  ('join', 18908),
#  ('team', 18812),
#  ('corbyn', 18498),
#  ('year', 18013),
#  ('britain', 17998),
#  ('lib', 17723),
#  ('ge2017', 17685),
#  ('years', 17424),
#  ('council', 17142),
#  ('tonight', 16602),
#  ('meeting', 16330),
#  ('debate', 16315),
#  ('london', 15769),
#  ('leave', 15708),
#  ('week', 15675),
#  ('mps', 15583),
#  ('candidate', 15481),
#  ('tax', 15227),
#  ('parliament', 15154),
#  ('care', 14249),
#  ('forward', 14227),
#  ('campaigning', 13917),
#  ('hope', 13892),
#  ('deal', 13887),
#  ('school', 13735),
#  ('country', 13509),
#  ('public', 13369),
#  ('health', 13183),
#  ('minister', 13123),
#  ('read', 13104),
#  ('working', 12968),
#  ('future', 12918),
#  ('meet', 12857),
#  ('cuts', 12837),
#  ('pm', 12820),
#  ('govt', 12781),
#  ('remain', 12763),
#  ('plan', 12751),
#  ('hard', 12726),
#  ('free', 12702),
#  ('rt', 12496),
#  ('police', 12350),
#  ('tomorrow', 12216),
#  ('community', 12207),
#  ('hear', 12193),
#  ('women', 12144),
#  ('voted', 12092),
#  ('leader', 11785),
#  ('fantastic', 11702),
#  ('proud', 11660),
#  ('british', 11654),
#  ('world', 11499),
#  ('strong', 11412),
#  ('big', 11344),
#  ('stop', 11312),
#  ('social', 11224),
#  ('jeremy', 11208),
#  ('funding', 11138),
#  ('young', 11091),
#  ('made', 11048),
#  ('conservative', 11016),
#  ('schools', 10871),
#  ('change', 10794),
#  ('event', 10751),
#  ('part', 10733),
#  ('find', 10730),
#  ('speech', 10656),
#  ('home', 10621),
#  ('business', 10618),
#  ('open', 10492),
#  ('members', 10395),
#  ('happy', 10316),
#  ('services', 10314),
#  ('dems', 10291),
#  ('children', 10284),
#  ('win', 10280),
#  ('voting', 10272),
#  ('supporting', 10184),
#  ('trump', 10174),
#  ('night', 10153),
#  ('pay', 10061),
#  ('national', 9957),
#  ('give', 9890),
#  ('real', 9888),
#  ('important', 9867),
#  ('agree', 9864),
#  ('residents', 9842),
#  ('evening', 9763),
#  ('visit', 9658),
#  ('put', 9633),
#  ('stand', 9624),
#  ('economy', 9556),
#  ('education', 9529),
#  ('jobs', 9476),
#  ('live', 9458),
#  ('plans', 9423),
#  ('show', 9367),
#  ('report', 9330),
#  ('referendum', 9315),
#  ('end', 9293),
#  ('north', 9259),
#  ('snp', 9229),
#  ('watch', 9188),
#  ('love', 9166),
#  ('full', 9153),
#  ('trade', 9142),
#  ('sign', 9133),
#  ('article', 9123),
#  ('voters', 9097),
#  ('brilliant', 8908),
#  ('response', 8886),
#  ('excellent', 8866),
#  ('talking', 8838),
#  ('rights', 8773),
#  ('manchester', 8750),
#  ('call', 8741),
#  ('email', 8681),
#  ('politics', 8618),
#  ('policy', 8618),
#  ('west', 8581),
#  ('service', 8516),
#  ('market', 8489),
#  ('clear', 8419),
#  ('huge', 8383),
#  ('house', 8336),
#  ('liberal', 8325),
#  ('start', 8280),
#  ('fight', 8276),
#  ('city', 8236),
#  ('housing', 8199),
#  ('staff', 8180),
#  ('manifesto', 8170),
#  ('days', 8157),
#  ('europe', 8103),
#  ('left', 8005),
#  ('money', 7974),
#  ('bill', 7970),
#  ('lots', 7958),
#  ('amazing', 7941),
#  ('june', 7903),
#  ('family', 7814),
#  ('dem', 7808),
#  ('making', 7804),
#  ('luck', 7721),
#  ('man', 7712),
#  ('single', 7672),
#  ('share', 7655),
#  ('job', 7639),
#  ('leadership', 7559),
#  ('coming', 7539),
#  ('long', 7536),
#  ('life', 7531),
#  ('taking', 7491),
#  ('st', 7469),
#  ('centre', 7440),
#  ('place', 7425),
#  ('top', 7361),
#  ('congratulations', 7298),
#  ('talk', 7291),
#  ('mayor', 7275),
#  ('launch', 7211),
#  ('question', 7129),
#  ('political', 7088),
#  ('action', 6982),
#  ('lovely', 6950),
#  ('attack', 6874),
#  ('labourdoorstep', 6867),
#  ('point', 6864),
#  ('friends', 6858),
#  ('cut', 6853),
#  ('general', 6847),
#  ('bbc', 6762),
#  ('park', 6751),
#  ('questions', 6749),
#  ('high', 6743),
#  ('case', 6651),
#  ('issues', 6642),
#  ('yesterday', 6640),
#  ('set', 6610),
#  ('office', 6594),
#  ('afternoon', 6546),
#  ('east', 6538),
#  ('ukip', 6532),
#  ('votelabour', 6531),
#  ('conservatives', 6508),
#  ('town', 6427),
#  ('speaking', 6377),
#  ('candidates', 6376),
#  ('south', 6376),
#  ('times', 6374),
#  ('secretary', 6347),
#  ('million', 6342),
#  ('euref', 6339),
#  ('standing', 6337),
#  ('result', 6304),
#  ('wrong', 6270),
#  ('remember', 6242),
#  ('workers', 6234),
#  ('david', 6233),
#  ('register', 6211),
#  ('green', 6169),
#  ('scotland', 6165),
#  ('speak', 6104),
#  ('street', 6100),
#  ('mental', 6067),
#  ('discuss', 6038),
#  ('state', 6032),
#  ('things', 6009),
#  ('westminster', 6008),
#  ('crisis', 6007),
#  ('road', 5999),
#  ('libdems', 5998),
#  ('christmas', 5980),
#  ('wales', 5977),
#  ('fair', 5961),
#  ('families', 5951),
#  ('message', 5924),
#  ('issue', 5923),
#  ('record', 5846),
#  ('thing', 5845),
#  ('protect', 5841),
#  ('means', 5838),
#  ('strongerin', 5831),
#  ('thoughts', 5807),
#  ('john', 5801),
#  ('delighted', 5785),
#  ('elected', 5773),
#  ('budget', 5771),
#  ('group', 5679),
#  ('chance', 5674),
#  ('final', 5672),
#  ('lost', 5666),
#  ('pleased', 5652),
#  ('save', 5640),
#  ('latest', 5583),
#  ('economic', 5552),
#  ('statement', 5552),
#  ('asked', 5541),
#  ('shows', 5516),
#  ('students', 5514),
#  ('thought', 5498),
#  ('prime', 5483),
#  ('bad', 5479),
#  ('security', 5449),
#  ('power', 5407),
#  ('opposition', 5397),
#  ('ahead', 5361),
#  ('wonderful', 5334),
#  ('bbcqt', 5233),
#  ('conference', 5214),
#  ('leaving', 5211),
#  ('decision', 5197),
#  ('run', 5183),
#  ('tim', 5171),
#  ('child', 5163),
#  ('petition', 5145),
#  ('positive', 5116),
#  ('makes', 5113),
#  ('post', 5096),
#  ('true', 5081),
#  ('stay', 5048),
#  ('joined', 5043),
#  ('england', 4963),
#  ('ago', 4957),
#  ('commons', 4956),
#  ('bit', 4946),
#  ('weekend', 4929),
#  ('investment', 4916),
#  ('answer', 4908),
#  ('union', 4903),
#  ('hall', 4902),
#  ('elections', 4892),
#  ('food', 4891),
#  ('democracy', 4883),
#  ('jo', 4882),
#  ('absolutely', 4872),
#  ('told', 4872),
#  ('member', 4871),
#  ('businesses', 4845),
#  ('sunday', 4832),
#  ('living', 4830),
#  ('votes', 4808),
#  ('calling', 4787),
#  ('scottish', 4781),
#  ('european', 4775),
#  ('pmqs', 4773),
#  ('number', 4761),
#  ('homes', 4753),
#  ('piece', 4751),
#  ('details', 4736),
#  ('choice', 4725),
#  ('act', 4678),
#  ('check', 4671),
#  ('deliver', 4669),
#  ('build', 4662),
#  ('safe', 4654),
#  ('lot', 4647),
#  ('called', 4644),
#  ('lead', 4626),
#  ('follow', 4591),
#  ('letter', 4571),
#  ('session', 4562),
#  ('constituency', 4542),
#  ('bring', 4531),
#  ('hours', 4514),
#  ('key', 4509),
#  ('met', 4506),
#  ('history', 4498),
#  ('story', 4487),
#  ('boris', 4458),
#  ('area', 4442),
#  ('risk', 4438),
#  ('march', 4429),
#  ('raise', 4425),
#  ('pledge', 4413),
#  ('fighting', 4395),
#  ('interesting', 4389),
#  ('lives', 4385),
#  ('face', 4383),
#  ('system', 4372),
#  ('helping', 4364),
#  ('parliamentary', 4364),
#  ('feel', 4337),
#  ('cllr', 4324),
#  ('saturday', 4314),
#  ('backing', 4310),
#  ('worth', 4308),
#  ('close', 4304),
#  ('media', 4298),
#  ('small', 4290),
#  ('continue', 4259),
#  ('interview', 4230),
#  ('sad', 4220),
#  ('idea', 4218),
#  ('views', 4208),
#  ('rise', 4204),
#  ('evidence', 4168),
#  ('running', 4155),
#  ('tells', 4145),
#  ('hospital', 4130),
#  ('calls', 4120),
#  ('book', 4097),
#  ('line', 4080),
#  ('cost', 4064),
#  ('impact', 4063),
#  ('forget', 4055),
#  ('united', 4053),
#  ('view', 4048),
#  ('station', 4034),
#  ('nice', 4005),
#  ('trust', 4001),
#  ('thursday', 3997),
#  ('lose', 3986),
#  ('fund', 3985),
#  ('hit', 3979),
#  ('early', 3977),
#  ('war', 3969),
#  ('due', 3966),
#  ('control', 3965),
#  ('law', 3959),
#  ('video', 3953),
#  ('libdemfightback', 3949),
#  ('bus', 3948),
#  ('friend', 3940),
#  ('send', 3931),
#  ('voice', 3929),
#  ('words', 3929),
#  ('pls', 3929),
#  ('twitter', 3914),
#  ('friday', 3895),
#  ('won', 3893),
#  ('needed', 3878),
#  ('committee', 3873),
#  ('joining', 3863),
#  ('turn', 3850),
#  ('person', 3849),
#  ('majority', 3832),
#  ('kind', 3828),
#  ('cameron', 3827),
#  ('energy', 3826),
#  ('farron', 3821),
#  ('front', 3813),
#  ('immigration', 3804),
#  ('including', 3803),
#  ('ready', 3796),
#  ('special', 3790),
#  ('half', 3781),
#  ('head', 3776),
#  ('giving', 3776),
#  ('tweet', 3766),
#  ('extra', 3761),
#  ('president', 3759),
#  ('beautiful', 3751),
#  ('leaders', 3750),
#  ('foreign', 3743),
#  ('ensure', 3743),
#  ('crime', 3736),
#  ('problem', 3734),
#  ('mark', 3727),
#  ('victims', 3724),
#  ('access', 3715),
#  ('vital', 3702),
#  ('involved', 3702),
#  ('democrats', 3690),
#  ('county', 3683),
#  ('increase', 3679),
#  ('ward', 3671),
#  ('woman', 3669),
#  ('weeks', 3658),
#  ('biggest', 3654),
#  ('hate', 3651),
#  ('listen', 3636),
#  ('opportunity', 3586),
#  ('hold', 3586),
#  ('chair', 3578),
#  ('human', 3577),
#  ('role', 3552),
#  ('shadow', 3549),
#  ('reading', 3525),
#  ('hustings', 3520),
#  ('poll', 3508),
#  ('transport', 3496),
#  ('welsh', 3486),
#  ('bbcdebate', 3486),
#  ('rail', 3482),
#  ('lab', 3470),
#  ('canvassing', 3468),
#  ('heart', 3468),
#  ('opening', 3459),
#  ('growth', 3447),
#  ('heard', 3446),
#  ('constituents', 3438),
#  ('charity', 3434),
#  ('advice', 3431),
#  ('bank', 3423),
#  ('kids', 3421),
#  ('poor', 3415),
#  ('press', 3414),
#  ('events', 3409),
#  ('court', 3392),
#  ('communities', 3386),
#  ('volunteers', 3379),
#  ('pleasure', 3361),
#  ('turnout', 3356),
#  ('respect', 3354),
#  ('fun', 3342),
#  ('air', 3334),
#  ('project', 3325),
#  ('benefit', 3323),
#  ('refugees', 3318),
#  ('word', 3316),
#  ('international', 3315),
#  ('car', 3309),
#  ('major', 3301),
#  ('planning', 3300),
#  ('greater', 3289),
#  ('low', 3275),
#  ('signed', 3271),
#  ('gov', 3267),
#  ('membership', 3259),
#  ('online', 3253),
#  ('moment', 3229),
#  ('policies', 3228),
#  ('justice', 3223),
#  ('white', 3209),
#  ('cox', 3208),
#  ('global', 3196),
#  ('ban', 3196),
#  ('challenge', 3192),
#  ('winning', 3185),
#  ('works', 3180),
#  ('understand', 3180),
#  ('polling', 3151),
#  ('building', 3148),
#  ('tv', 3147),
#  ('train', 3139),
#  ('independent', 3134),
#  ('seat', 3123),
#  ('councillors', 3118),
#  ('months', 3117),
#  ('research', 3114),
#  ('birthday', 3103),
#  ('earlier', 3099),
#  ('offer', 3097),
#  ('councillor', 3096),
#  ('leading', 3095),
#  ('discussion', 3093),
#  ('address', 3092),
#  ('society', 3076),
#  ('parents', 3075),
#  ('supporters', 3065),
#  ('johnson', 3061),
#  ('massive', 3060),
#  ('waiting', 3053),
#  ('worse', 3044),
#  ('men', 3042),
#  ('citizens', 3042),
#  ('concerns', 3041),
#  ('raised', 3040),
#  ('central', 3036),
#  ('takes', 3031),
#  ('found', 3031),
#  ('michael', 3025),
#  ('commitment', 3023),
#  ('results', 3023),
#  ('cabinet', 3020),
#  ('retweet', 3019),
#  ('farage', 3015),
#  ('miss', 3009),
#  ('tackle', 3007),
#  ('round', 3002),
#  ('paul', 3000),
#  ('poverty', 2999),
#  ('missed', 2998),
#  ('play', 2989),
#  ('fire', 2987),
#  ('sir', 2983),
#  ('page', 2974),
#  ('drop', 2972),
#  ('delivering', 2970),
#  ('stronger', 2970),
#  ('primary', 2964),
#  ('club', 2956),
#  ('strategy', 2955),
#  ('celebrate', 2944),
#  ('emergency', 2933),
#  ('past', 2928),
#  ('difference', 2926),
#  ('industry', 2925),
#  ('discussing', 2924),
#  ('glad', 2920),
#  ('move', 2917),
#  ('lord', 2915),
#  ('affected', 2906),
#  ('talks', 2904),
#  ('coalition', 2903),
#  ('info', 2902),
#  ('enjoyed', 2901),
#  ('abuse', 2899),
#  ('busy', 2896),
#  ('george', 2895),
#  ('stable', 2884),
#  ('supported', 2882),
#  ('officers', 2868),
#  ('thinking', 2858),
#  ('thousands', 2854),
#  ('celebrating', 2843),
#  ('polls', 2842),
#  ('gain', 2841),
#  ('asks', 2837),
#  ('showing', 2831),
#  ('disabled', 2828),
#  ('promise', 2818),
#  ('church', 2817),
#  ('class', 2813),
#  ('paid', 2804),
#  ('month', 2797),
#  ('seats', 2797),
#  ('spending', 2791),
#  ('force', 2789),
#  ('fab', 2788),
#  ('side', 2781),
#  ('happen', 2771),
#  ('putting', 2758),
#  ('figures', 2757),
#  ('benefits', 2756),
#  ('position', 2755),
#  ('moving', 2752),
#  ('congrats', 2751),
#  ('paper', 2742),
#  ('improve', 2741),
#  ('game', 2736),
#  ('reason', 2735),
#  ('death', 2734),
#  ('success', 2734),
#  ('wait', 2730),
#  ('colleagues', 2726),
#  ('donald', 2725),
#  ('website', 2723),
#  ('failed', 2721),
#  ('raising', 2721),
#  ('parties', 2716),
#  ('link', 2715),
#  ('surgery', 2696),
#  ('vision', 2690),
#  ('ministers', 2690),
#  ('rate', 2689),
#  ('private', 2689),
#  ('chancellor', 2686),
#  ('skills', 2681),
#  ('announced', 2681),
#  ('listening', 2678),
#  ('dementia', 2673),
#  ('late', 2673),
#  ('daily', 2670),
#  ('experience', 2662),
#  ('victory', 2661),
#  ('review', 2660),
#  ('contact', 2657),
#  ('smith', 2657),
#  ('account', 2654),
#  ('list', 2647),
#  ('hand', 2647),
#  ('income', 2639),
#  ('monday', 2629),
#  ('touch', 2627),
#  ('spent', 2625),
#  ('performance', 2624),
#  ('sun', 2616),
#  ('sector', 2614),
#  ('voteleave', 2606),
#  ('syria', 2602),
#  ('bridge', 2599),
#  ('april', 2598),
#  ('safety', 2598),
#  ('chief', 2592),
#  ('comments', 2591),
#  ('provide', 2589),
#  ('hour', 2589),
#  ('sense', 2580),
#  ('learn', 2579),
#  ('rest', 2577),
#  ('award', 2576),
#  ('written', 2573),
#  ('values', 2572),
#  ('movement', 2570),
#  ('politicians', 2567),
#  ('lords', 2567),
#  ('interest', 2564),
#  ('catch', 2561),
#  ('level', 2557),
#  ('step', 2555),
#  ('watching', 2554),
#  ('fact', 2548),
#  ('nick', 2540),
#  ('consultation', 2537),
#  ('photo', 2534),
#  ('hearing', 2533),
#  ('attacks', 2533),
#  ('points', 2532),
#  ('aid', 2532),
#  ('negotiations', 2522),
#  ('red', 2522),
#  ('spend', 2509),
#  ('stuff', 2503),
#  ('defence', 2501),
#  ('problems', 2501),
#  ('shame', 2482),
#  ('current', 2479),
#  ('marr', 2476),
#  ('spoke', 2474),
#  ('blog', 2471),
#  ('festival', 2469),
#  ('leeds', 2460),
#  ('mail', 2457),
#  ('training', 2455),
#  ('helped', 2453),
#  ('based', 2448),
#  ('awards', 2443),
#  ('claim', 2441),
#  ('held', 2440),
#  ('countries', 2438),
#  ('secure', 2435),
#  ('claims', 2434),
#  ('powerful', 2432),
#  ('battle', 2431),
#  ('fear', 2429),
#  ('chaos', 2429),
#  ('threat', 2429),
#  ('create', 2424),
#  ('reasons', 2412),
#  ('democrat', 2403),
#  ('pretty', 2400),
#  ('councils', 2396),
#  ('official', 2388),
#  ('bristol', 2387),
#  ('add', 2384),
#  ('libdem', 2381),
#  ('numbers', 2379),
#  ('walk', 2366),
#  ('led', 2366),
#  ('longer', 2360),
#  ('short', 2349),
#  ('personal', 2349),
#  ('minutes', 2345),
#  ('importance', 2340),
#  ('matter', 2327),
#  ('patients', 2327),
#  ('royal', 2326),
#  ('owen', 2325),
#  ('visiting', 2316),
#  ('incredible', 2316),
#  ('peace', 2315),
#  ('youth', 2315),
#  ('wanted', 2311),
#  ('holding', 2307),
#  ('football', 2307),
#  ('died', 2304),
#  ('progress', 2300),
#  ('financial', 2299),
#  ('starting', 2298),
#  ('cancer', 2296),
#  ('attend', 2290),
#  ('reception', 2286),
#  ('legal', 2283),
#  ('buy', 2281),
#  ('steel', 2277),
#  ('sturgeon', 2275),
#  ('credit', 2274),
#  ('happened', 2267),
#  ('recent', 2267),
#  ('worst', 2266),
#  ('higher', 2265),
#  ('chris', 2263),
#  ('quality', 2262),
#  ('door', 2258),
#  ('launched', 2257),
#  ('facebook', 2256),
#  ('wage', 2255),
#  ('facts', 2254),
#  ('honour', 2251),
#  ('billion', 2249),
#  ('rally', 2247),
#  ('copeland', 2235),
#  ('gave', 2230),
#  ('employment', 2228),
#  ('focus', 2228),
#  ('mind', 2223),
#  ('motion', 2220),
#  ('agreed', 2218),
#  ('hands', 2212),
#  ('phone', 2212),
#  ('finally', 2211),
#  ('mr', 2209),
#  ('cross', 2208),
#  ('scheme', 2206),
#  ('room', 2203),
#  ('independence', 2200),
#  ('term', 2199),
#  ('rules', 2193),
#  ('teachers', 2191),
#  ('andrew', 2190),
#  ('climate', 2188),
#  ('return', 2187),
#  ('stoke', 2187),
#  ('accept', 2183),
#  ('sec', 2177),
#  ('wins', 2174),
#  ('areas', 2174),
#  ('failure', 2167),
#  ('lack', 2165),
#  ('started', 2162),
#  ('doorstep', 2152),
#  ('truth', 2152),
#  ('annual', 2149),
#  ('osborne', 2147),
#  ('millions', 2145),
#  ('development', 2141),
#  ('reform', 2140),
#  ('black', 2137),
#  ('spot', 2136),
#  ('deserve', 2136),
#  ('break', 2132),
#  ('lies', 2129),
#  ('cambridge', 2123),
#  ('worked', 2121),
#  ('music', 2117),
#  ('board', 2113),
#  ('violence', 2110),
#  ('approach', 2110),
#  ('simply', 2109),
#  ('interested', 2109),
#  ('tribute', 2104),
#  ('nicola', 2101),
#  ('doors', 2096),
#  ('totally', 2090),
#  ('library', 2085),
#  ('weather', 2085),
#  ('terrible', 2083),
#  ('nation', 2083),
#  ('announce', 2079),
#  ('teams', 2076),
#  ('chat', 2073),
#  ('ideas', 2072),
#  ('invest', 2070),
#  ('opportunities', 2068),
#  ('awareness', 2066),
#  ('hunt', 2066),
#  ('loved', 2065),
#  ('common', 2064),
#  ('missing', 2061),
#  ('committed', 2054),
#  ('grammar', 2050),
#  ('inquiry', 2048),
#  ('pupils', 2048),
#  ('terror', 2043),
#  ('richmond', 2040),
#  ('solidarity', 2038),
#  ('nurses', 2034),
#  ('birmingham', 2034),
#  ('received', 2032),
#  ('closed', 2032),
#  ('panel', 2031),
#  ('apply', 2030),
#  ('freedom', 2029),
#  ('registered', 2028),
#  ('streets', 2028),
#  ('vulnerable', 2027),
#  ('enjoy', 2024),
#  ('gove', 2021),
#  ('starts', 2019),
#  ('doctors', 2017),
#  ('rule', 2015),
#  ('information', 2014),
#  ('data', 2014),
#  ('james', 2014),
#  ('dear', 2013),
#  ('fees', 2012),
#  ('waspi', 2011),
#  ('equality', 2011),
#  ('audience', 2009),
#  ('hill', 2009),
#  ('reality', 2008),
#  ('promised', 2007),
#  ('scrap', 2006),
#  ('telling', 2003),
#  ('difficult', 2000),
#  ('growing', 2000),
#  ('programme', 2000),
#  ('keeping', 1994),
#  ('liverpool', 1993),
#  ('tickets', 1992),
#  ('happening', 1990),
#  ('water', 1988),
#  ('votelibdem', 1982),
#  ('debt', 1981),
#  ('nigel', 1979),
#  ('clean', 1975),
#  ('promises', 1975),
#  ('summer', 1974),
#  ('form', 1972),
#  ('superb', 1972),
#  ('priority', 1970),
#  ('oppose', 1964),
#  ('facing', 1957),
#  ('ldconf', 1956),
#  ('answers', 1950),
#  ('unite', 1950),
#  ('film', 1945),
#  ('warm', 1944),
#  ('process', 1943),
#  ('update', 1938),
#  ('places', 1938),
#  ('winter', 1936),
#  ('loss', 1930),
#  ('fox', 1930),
#  ('completely', 1927),
#  ('killed', 1927),
#  ('backzac2016', 1925),
#  ('forces', 1924),
#  ('wishes', 1918),
#  ('explain', 1918),
#  ('rain', 1918),
#  ('beat', 1918),
#  ('inspiring', 1915),
#  ('costs', 1915),
#  ('comment', 1911),
#  ('excited', 1908),
#  ('garden', 1903),
#  ('selected', 1899),
#  ('thinks', 1898),
#  ('breaking', 1897),
#  ('challenges', 1891),
#  ('france', 1889),
#  ('pressure', 1889),
#  ('tooting', 1886),
#  ('environment', 1883),
#  ('age', 1882),
#  ('amendment', 1879),
#  ('student', 1878),
#  ('refugee', 1876),
#  ('sunny', 1874),
#  ('mayoral', 1874),
#  ('reports', 1872),
#  ('terms', 1871),
#  ('tour', 1870),
#  ('art', 1870),
#  ('order', 1870),
#  ('leaflets', 1868),
#  ('female', 1868),
#  ('pledges', 1866),
#  ('cap', 1866),
#  ('site', 1859),
#  ('sat', 1856),
#  ('write', 1855),
#  ('dinner', 1854),
#  ('boost', 1853),
#  ('ppl', 1851),
#  ('shocking', 1850),
#  ('fully', 1848),
#  ('fine', 1845),
#  ('changed', 1844),
#  ('represent', 1841),
#  ('total', 1840),
#  ('failing', 1836),
#  ('edinburgh', 1835),
#  ('companies', 1833),
#  ('race', 1832),
#  ('intogether', 1830),
#  ('reminder', 1829),
#  ('champion', 1828),
#  ('broken', 1823),
#  ('ge17', 1822),
#  ('decent', 1821),
#  ('science', 1821),
#  ('mention', 1818),
#  ('sutton', 1818),
#  ('published', 1811),
#  ('english', 1806),
#  ('playing', 1805),
#  ('campaigners', 1801),
#  ('prison', 1799),
#  ('awful', 1799),
#  ('generation', 1797),
#  ('sharing', 1791),
#  ('fall', 1789),
#  ('sort', 1787),
#  ('concerned', 1787),
#  ('affordable', 1787),
#  ('forced', 1786),
#  ('coffee', 1783),
#  ('hosting', 1780),
#  ('colleague', 1775),
#  ('democratic', 1774),
#  ('travel', 1773),
#  ('concern', 1772),
#  ('favourite', 1771),
#  ('cardiff', 1764),
#  ('chamber', 1759),
#  ('indyref2', 1759),
#  ('forthemany', 1756),
#  ('girls', 1756),
#  ('demand', 1755),
#  ('blue', 1753),
#  ('whilst', 1752),
#  ('apprenticeships', 1751),
#  ('waste', 1749),
#  ('sadly', 1746),
#  ('writes', 1742),
#  ('cutting', 1740),
#  ('stage', 1738),
#  ('andy', 1738),
#  ('successful', 1737),
#  ('delivered', 1735),
#  ('surely', 1734),
#  ('taxes', 1733),
#  ('dog', 1733),
#  ('strike', 1729),
#  ('disability', 1727),
#  ('tony', 1724),
#  ('light', 1722),
#  ('cllrs', 1722),
#  ('officer', 1721),
#  ('main', 1719),
#  ('holiday', 1718),
#  ('progressive', 1714),
#  ('battlefornumber10', 1714),
#  ('target', 1711),
#  ('austerity', 1711),
#  ('trail', 1710),
#  ('lunch', 1710),
#  ('price', 1710),
#  ('labourinforbritain', 1708),
#  ...]

# %% [markdown]
# ## Combine Features

# %%
df_2017_2p = pd.read_csv('2017_SP_candidates.csv')

# %%
df_2017_2p = df_2017_2p.drop(['Unnamed: 0'], axis=1)
df_2017_2p.head()
# Out:
#               name  gender  birth_date                       party_name  \
# 0  Stephen Kinnock    male  1970-01-01                     Labour Party
# 1     Cen Phillips    male        1971                Liberal Democrats
# 2      Sadie Vidal  female         NaN  Conservative and Unionist Party
# 3        Guto Bebb    male  1968-10-09  Conservative and Unionist Party
# 4       Emily Owen  Female        1995                     Labour Party
#
#   post_label elected twitter_username     twitter_user_id
# 0   Aberavon    True         SKinnock           722347303
# 1   Aberavon   False            CenLD          1872769464
# 2   Aberavon   False       sadievidal            19447175
# 3  Aberconwy    True    GutoAberconwy  752820350371717120
# 4  Aberconwy   False  Emily4Aberconwy            92363214

# %%
mps_list = df_2017_2p.twitter_username.tolist()

# %%
len(set(mps_list))
# Out:
# 1454

# %%
len(df_features)
# Out:
# 1314

# %%
df_features_new = df_features[(df_features['twitter_username'].isin(mps_list) == True)]

# %%
new_mps_list = df_features_new.twitter_username.tolist()
len(new_mps_list)
# Out:
# 1304

# %%
df_2017_2p_new = df_2017_2p[(df_2017_2p['twitter_username'].isin(new_mps_list) == True)]

# %%
result = pd.merge(df_2017_2p_new, df_features_new, on='twitter_username', how='left')

# %%
result
# Out:
#                              name  gender  birth_date  \
# 0                 Stephen Kinnock    male  1970-01-01
# 1                    Cen Phillips    male        1971
# 2                     Sadie Vidal  female         NaN
# 3                       Guto Bebb    male  1968-10-09
# 4                      Emily Owen  Female        1995
# 5                 Isobel Davidson  female         NaN
# 6                  Grace O'Keeffe  female         NaN
# 7                    Orr Vinegold    male        1988
# 8                  Callum O'Dwyer    Male         NaN
# 9                    Ross Thomson    male  1987-09-21
# 10                   Jenny Wilson  female         NaN
# 11                Helen McFarlane  female         NaN
# 12                   Leo Docherty    male         NaN
# 13                   Alan Hilliar    male         NaN
# 14                   Gary Puffett    male         NaN
# 15                    John Fisher    male         NaN
# 16                    Ian Garrett    male  1965-11-25
# 17                   Wendy Morton  female  1967-11-09
# 18                    Jane Brophy  female        1963
# 19                 Andrew Western    male         NaN
# 20                 Laura Knightly  female         NaN
# 21                      Mark Tami    male  1962-10-03
# 22                   James Dawson    Male  1984-10-21
# 23                     Kate Smith  female  1957-06-04
# 24               William Campbell    male        1954
# 25                  Kirstene Hair  Female         NaN
# 26                  Clive Sneddon    male         NaN
# 27          Mary Griffiths Clarke  female         NaN
# 28                      Alan Reid    male  1954-08-07
# 29                  Caroline Fife  female         NaN
# ...                           ...     ...         ...
# 1275                Emma Reynolds  female  1977-11-02
# 1276                   Ben Mathis    Male  1982-04-01
# 1277                 Pat McFadden    male  1965-03-26
# 1278                Kieran Mullan    male         NaN
# 1283   673138      2537        137    1524     426    0.086381  0.960908
# 1284    44476         1          2       5       3    0.400000  1.000000
# 1285   167791       660        435     900     573    0.359801  0.744417
# 1286   809194      6350        222    1903     348    0.107350  0.920213
# 1287  2600058      1420        336    2536    1130    0.121081  0.913874
# 1288   788263       178         47    2644     299    0.016526  0.929677
# 1289    59020     12952        514    2657    1672    0.182918  0.945552
# 1290   504546      5948       1095    2174    1729    0.384345  0.763075
# 1291   386023      5665        363    2550     764    0.124742  0.876289
# 1292    68627        86         30     117      49    0.254237  0.991525
# 1293       66        63         36      49      43    0.720000  0.980000
# 1294   163649       750        160    1346     191    0.118343  0.995562
# 1295      306       114          3       5       4    0.600000  1.000000
# 1296   377656       200         37     144      63    0.250000  0.972973
# 1297  1896444       840        456    1147     854    0.385787  0.970389
# 1298   310054      1587         94     832     302    0.112981  1.000000
# 1299     2370         5          4      39      12    0.097561  0.951220
# 1300   153775      5240        230    1466     591    0.147910  0.942765
# 1301   172611      4581        831    1851    1493    0.361776  0.805834
# 1302  1300969      4061        606    2438     829    0.226457  0.911061
# 1303  1034698      1129        202     949     351    0.192564  0.904671
# 1304     5301       611         60     167     182    0.289855  0.806763
#
#        reweet%
# 0     0.468475
# 1     0.231594
# 2     0.545455
# 3     0.259701
# 4     0.616046
# 5     0.767164
# 6     0.508197
# 7     0.090909
# 8     0.628616
# 9     0.351002
# 10    0.516014
# 11    0.568000
# 12    0.368000
# 13    0.000000
# 14    0.200827
# 15    0.197183
# 16    1.000000
# 17    0.403226
# 18    0.228377
# 19    0.362069
# 20    0.598639
# 21    0.450056
# 22    0.633221
# 23    1.000000
# 24    0.522727
# 25    0.605634
# 26    0.934911
# 27    0.602302
# 28    1.000000
# 29    0.580110
# ...        ...
# 1275  0.396574
# 1276  0.888235
# 1277  0.449239
# 1278  0.571429
# 1279  0.745763
# 1280  0.471545
# 1281  0.344196
# 1282  0.347413
# 1283  0.268600
# 1284  0.600000
# 1285  0.473945
# 1286  0.168279
# 1287  0.407207
# 1288  0.105134
# 1289  0.595018
# 1290  0.606880
# 1291  0.262543
# 1292  0.415254
# 1293  0.860000
# 1294  0.141272
# 1295  0.800000
# 1296  0.425676
# 1297  0.722504
# 1298  0.362981
# 1299  0.292683
# 1300  0.380064
# 1301  0.649978
# 1302  0.309791
# 1303  0.334604
# 1304  0.879227
#
# [1305 rows x 19 columns]

# %%
result.birth_date = result.birth_date.fillna('2017-00-00')
result.birth_date = result.birth_date.apply(lambda x: (2017 - int(x[0:4])))

# %%
len(result)
# Out:
# 1305

# %%
result = result.drop_duplicates(subset='twitter_username', keep="last")

# %%
result.head()
# Out:
#               name  gender  birth_date                       party_name  \
# 0  Stephen Kinnock    male          47                     Labour Party
# 1     Cen Phillips    male          46                Liberal Democrats
# 2      Sadie Vidal  female           0  Conservative and Unionist Party
# 3        Guto Bebb    male          49  Conservative and Unionist Party
# 4       Emily Owen  Female          22                     Labour Party
#
#   post_label elected twitter_username     twitter_user_id  tweets_count  \
# 0   Aberavon    True         SKinnock           722347303          2617
# 1   Aberavon   False            CenLD          1872769464          2798
# 2   Aberavon   False       sadievidal            19447175            22
# 3  Aberconwy    True    GutoAberconwy  752820350371717120           335
# 4  Aberconwy   False  Emily4Aberconwy            92363214           698
#
#    followers  friends  retweet  favrotes  mentioned  quoted  reweet  \
# 0      15315     1239    91268     13779        574    2475    1226
# 1       1458     2680  3628547      1376        559    2734     648
# 2        344      368    30248        10          5      21      12
# 3        553       30    14791        24         87     335      87
# 4       1292      918   562405      1880        204     627     430
#
#    mentioned%   quoted%   reweet%
# 0    0.219335  0.945739  0.468475
# 1    0.199786  0.977127  0.231594
# 2    0.227273  0.954545  0.545455
# 3    0.259701  1.000000  0.259701
# 4    0.292264  0.898281  0.616046

# %% [markdown]
# ## Topic Count feature

# %%
###get topic list
def getList(ListFileName):
    #read the list file and build a list
    read_list = []

    fp = open(ListFileName, 'r')
    line = fp.readline()
    while line:
        word = line.strip()
        w = word.lower()
        read_list.append(w)
        line = fp.readline()
    fp.close()
    return read_list

topic_list = []

# st = open('stopword_large.txt', 'r')
topic_list = getList('Policy_topic_words.txt')

# %%
topic_list
# Out:
# ['generalelection',
#  'ge',
#  'labour',
#  'brexit',
#  'nhs',
#  'conservatives',
#  'snp',
#  'terrorist',
#  'young',
#  'government',
#  'together',
#  'people',
#  'uk',
#  'eruope',
#  'eu',
#  'support',
#  'debate',
#  'enemies',
#  'hungry',
#  'britain',
#  'agriculture',
#  'animals',
#  'fisheries',
#  'forestry',
#  'agricultural',
#  'policy',
#  'countryside',
#  'asylum',
#  'immigration',
#  'nationality',
#  'business',
#  'support',
#  'companies',
#  'competition',
#  'charities',
#  'children',
#  'families',
#  'death',
#  'administration',
#  'justice',
#  'prison',
#  'gambling',
#  'cultural',
#  'heritage',
#  'arts',
#  'armed',
#  'forces',
#  'defence',
#  'equipment',
#  'economic',
#  'situation',
#  'education',
#  'employment',
#  'climate',
#  'energy',
#  'environmental',
#  'protection',
#  'diseases',
#  'health',
#  'housing',
#  'africa',
#  'arms',
#  'asia',
#  'syria',
#  'isis',
#  'government',
#  'information',
#  'technology',
#  'innovation',
#  'administration',
#  'services',
#  'care',
#  'aviation',
#  'railways',
#  'roads',
#  'loans',
#  'utilities',
#  'older',
#  'marriage',
#  'divorce',
#  'law',
#  'gender',
#  'lsbt',
#  'offences',
#  'discrimination',
#  'freedom',
#  'privacy',
#  'olympic',
#  'budget',
#  'mortgages',
#  'international',
#  'relations',
#  'insurance',
#  'iraq',
#  'welfare',
#  'military',
#  'unemployment',
#  'nuclear',
#  'electricity',
#  'wildlife',
#  'waste',
#  'industry',
#  'grant',
#  'council',
#  'parliament',
#  'experiments',
#  'overcrowding',
#  'homelessness',
#  'supply',
#  'regeneration',
#  'russia',
#  'overseas',
#  'america',
#  'civil',
#  'internet',
#  'benefits',
#  'pensions',
#  'buses',
#  'underground',
#  'cycling',
#  'jobs',
#  'campaign',
#  'tax',
#  'residents']

# %%
# Topic_searched = []
# Topic_frequency = {}
topic_count = 0
twitter_count = 1
temp = []
previous_name = "213zsj"

for index, row in df_cleaned.iterrows():
    if previous_name != row.screen_name:
        topic_ratio = topic_count/twitter_count
        temp.append([previous_name,topic_count,topic_ratio])
        previous_name = row.screen_name
        topic_count = 0
        twitter_count = 1
        words = row.text.split()
        for w in words:
            #replace two or more with two occurrences
            w = replaceTwoOrMore(w)
            #strip punctuation
            w = w.strip('\'"?,.')
            #ignore if it is a stop word
            w = w.lower()
            if w in topic_list:
#                 Topic_searched.append(w)
#                 count = frequency.get(w,0)
#                 frequency[w] = count + 1
                topic_count += 1
                break
            
        else:
            continue
    
    else:

        words = row.text.split()
        for w in words:
            #replace two or more with two occurrences
            w = replaceTwoOrMore(w)
            #strip punctuation
            w = w.strip('\'"?,.')
            #ignore if it is a stop word
            w = w.lower()
            twitter_count += 1
            if w in topic_list:
#                 Topic_searched.append(w)
#                 count = frequency.get(w,0)
#                 frequency[w] = count + 1
                topic_count += 1
                
                break
            else:
                continue
        
temp.append([previous_name,topic_count,topic_ratio])

# %%
temp.append([previous_name,topic_count,topic_ratio])
feature_columns = ['twitter_username', 'topic_count', 'topic_ratio']
df_topic_features = pd.DataFrame(data=temp, columns=feature_columns)

# %%
df_topic_features = df_topic_features.drop_duplicates(subset='twitter_username', keep="last")

# %%
len(df_topic_features)
# Out:
# 1316

# %%
df_topic_features = df_topic_features.drop([0])

# %%
result_with_topic = pd.merge(result, df_topic_features, on='twitter_username', how='left')

# %%
result_with_topic
# Out:
#                              name  gender  birth_date  \
# 0                 Stephen Kinnock    male          47
# 1                    Cen Phillips    male          46
# 2                     Sadie Vidal  female           0
# 3                       Guto Bebb    male          49
# 4                      Emily Owen  Female          22
# 5                 Isobel Davidson  female           0
# 6                  Grace O'Keeffe  female           0
# 7                    Orr Vinegold    male          29
# 8                  Callum O'Dwyer    Male           0
# 9                    Ross Thomson    male          30
# 10                   Jenny Wilson  female           0
# 11                Helen McFarlane  female           0
# 12                   Leo Docherty    male           0
# 13                   Alan Hilliar    male           0
# 14                   Gary Puffett    male           0
# 15                    John Fisher    male           0
# 16                    Ian Garrett    male          52
# 17                   Wendy Morton  female          50
# 18                    Jane Brophy  female          54
# 19                 Andrew Western    male           0
# 20                 Laura Knightly  female           0
# 21                      Mark Tami    male          55
# 22                   James Dawson    Male          33
# 23                     Kate Smith  female          60
# 24               William Campbell    male          63
# 25                  Kirstene Hair  Female           0
# 26                  Clive Sneddon    male           0
# 27          Mary Griffiths Clarke  female           0
# 28                      Alan Reid    male          63
# 29                  Caroline Fife  female           0
# ...                           ...     ...         ...
# 1274                Emma Reynolds  female          40
# 1275                   Ben Mathis    Male          35
# 1276                 Pat McFadden    male          52
# 1277                Kieran Mullan    male           0
# 1278                Sarah Quarmby  female          26
# 1279              Stephen Kearney    Male           0
# 1280                  Joy Squires  Female          63
# 1281                 Robin Walker    Male          39
# 1282                   Sue Hayman  female          55
# 1283                Phill Roberts    male           0
# 1284                  Clark Vasey    male           0
# 1285               Barbara Keeley  female          65
# 1286                 Iain Lindley    male          34
# 1287                 Hazel Thorpe  female           0
FileName, 'r')
    line = fp.readline()
    while line:
        word = line.strip()
#         w = word.lower()
        read_list.append(word)
        line = fp.readline()
    fp.close()
    return read_list

former_mp17 = getMPList('former_mp17.txt')

# %%
len(former_mp17)
# Out:
# 661

# %%
result_with_topic['former_MP'] = result_with_topic.name.apply(lambda x: 'yes' if x in former_mp17 else 'no')

# %%
result_with_topic.head()
# Out:
#               name  gender  birth_date                       party_name  \
# 0  Stephen Kinnock    male          47                     Labour Party
# 1     Cen Phillips    male          46                Liberal Democrats
# 2      Sadie Vidal  female           0  Conservative and Unionist Party
# 3        Guto Bebb    male          49  Conservative and Unionist Party
# 4       Emily Owen  Female          22                     Labour Party
#
#   post_label elected twitter_username     twitter_user_id  tweets_count  \
# 0   Aberavon    True         SKinnock           722347303          2617
# 1   Aberavon   False            CenLD          1872769464          2798
# 2   Aberavon   False       sadievidal            19447175            22
# 3  Aberconwy    True    GutoAberconwy  752820350371717120           335
# 4  Aberconwy   False  Emily4Aberconwy            92363214           698
#
#    followers    ...      favrotes  mentioned  quoted  reweet  mentioned%  \
# 0      15315    ...         13779        574    2475    1226    0.219335
# 1       1458    ...          1376        559    2734     648    0.199786
# 2        344    ...            10          5      21      12    0.227273
# 3        553    ...            24         87     335      87    0.259701
# 4       1292    ...          1880        204     627     430    0.292264
#
#     quoted%   reweet%  topic_count  topic_ratio  former_MP
# 0  0.945739  0.468475         1150     0.033055        yes
# 1  0.977127  0.231594         1199     0.029486         no
# 2  0.954545  0.545455            6     0.017910         no
# 3  1.000000  0.259701           78     0.016807        yes
# 4  0.898281  0.616046          238     0.025895         no
#
# [5 rows x 22 columns]

# %%
result_with_topic.to_csv('All_data_large_2017.csv')

# %%
len(result_with_topic)
# Out:
# 1304

# %% [markdown]
# ## Add sentiment feature

# %%
df_sentiment_features = pd.read_csv('17sentiment_features.csv')

# %%
df_sentiment_features.head()
# Out:
#    Unnamed: 0 twitter_username  tweets_count  postive  negative  \
# 0           1         SKinnock          2617      927      1690
# 1           2            CenLD          2798      942      1856
# 2           3       sadievidal            22       12        10
# 3           4    GutoAberconwy           335      122       213
# 4           5  Emily4Aberconwy           698      264       434
#
#    sum_sentiment  postive_r  negative_r
# 0         -720.4   0.354222    0.645778
# 1         -831.6   0.336669    0.663331
# 2            1.6   0.545455    0.454545
# 3          -85.6   0.364179    0.635821
# 4         -158.2   0.378223    0.621777

# %%
len(df_sentiment_features)
# Out:
# 1315

# %%
df_sentiment_features = df_sentiment_features.drop_duplicates(subset='twitter_username', keep="last")

# %%
len(df_sentiment_features)
# Out:
# 1314

# %%
df_sentiment_features = df_sentiment_features[(df_sentiment_features['twitter_username'].isin(mps_list) == True)]

# %%
len(df_sentiment_features)
# Out:
# 1304

# %%
result_with_topic_S = pd.merge(result_with_topic, df_sentiment_features, on='twitter_username', how='left')

# %%
result_with_topic_S = result_with_topic_S.drop(['Unnamed: 0'], axis=1)
result_with_topic_S.head()
# Out:
#               name  gender  birth_date                       party_name  \
# 0  Stephen Kinnock    male          47                     Labour Party
# 1     Cen Phillips    male          46                Liberal Democrats
# 2      Sadie Vidal  female           0  Conservative and Unionist Party
# 3        Guto Bebb    male          49  Conservative and Unionist Party
# 4       Emily Owen  Female          22                     Labour Party
#
#   post_label elected twitter_username     twitter_user_id  tweets_count_x  \
# 0   Aberavon    True         SKinnock           722347303            2617
# 1   Aberavon   False            CenLD          1872769464            2798
# 2   Aberavon   False       sadievidal            19447175              22
# 3  Aberconwy    True    GutoAberconwy  752820350371717120             335
# 4  Aberconwy   False  Emily4Aberconwy            92363214             698
#
#    followers     ...       reweet%  topic_count  topic_ratio  former_MP  \
# 0      15315     ...      0.468475         1150     0.033055        yes
# 1       1458     ...      0.231594         1199     0.029486         no
# 2        344     ...      0.545455            6     0.017910         no
# 3        553     ...      0.259701           78     0.016807        yes
# 4       1292     ...      0.616046          238     0.025895         no
#
#    tweets_count_y  postive  negative  sum_sentiment  postive_r  negative_r
# 0            2617      927      1690         -720.4   0.354222    0.645778
# 1            2798      942      1856         -831.6   0.336669    0.663331
# 2              22       12        10            1.6   0.545455    0.454545
# 3             335      122       213          -85.6   0.364179    0.635821
# 4             698      264       434         -158.2   0.378223    0.621777
#
# [5 rows x 28 columns]

# %%
result_with_topic.to_csv('All_data_large_2017_S.csv')

# %%
result_with_topic = pd.read_csv('All_data_large_2017_S.csv')

# %%
result_with_topic.drop(['former_MP'], axis=1)
# Out:
#       Unnamed: 0                         name  gender  birth_date  \
# 0              0              Stephen Kinnock    male          47
# 1              1                 Cen Phillips    male          46
# 2              2                  Sadie Vidal  female           0
# 3              3                    Guto Bebb    male          49
# 4              4                   Emily Owen  Female          22
# 5              5              Isobel Davidson  female           0
# 6              6               Grace O'Keeffe  female           0
# 7              7                 Orr Vinegold    male          29
# 8              8               Callum O'Dwyer    Male           0
# 9              9                 Ross Thomson    male          30
# 10            10                 Jenny Wilson  female           0
# 11            11              Helen McFarlane  female           0
# 12            12                 Leo Docherty    male           0
# 13            13                 Alan Hilliar    male           0
# 14            14                 Gary Puffett    male           0
# 15            15                  John Fisher    male           0
# 16            16                  Ian Garrett    male          52
# 17            17                 Wendy Morton  female          50
# 18            18                  Jane Brophy  female          54
# 19            19               Andrew Western    male           0
# 20            20               Laura Knightly  female           0
# 21            21                    Mark Tami    male          55
# 22            22                 James Dawson    Male          33
# 23            23                   Kate Smith  female          60
# 24            24             William Campbell    male          63
# 25            25                Kirstene Hair  Female           0
# 26            26                Clive Sneddon    male           0
# 27            27        Mary Griffiths Clarke  female           0
# 28            28                    Alan Reid    male          63
# 29            29                Caroline Fife  female           0
# ...          ...                          ...     ...         ...
# 1274        1274                Emma Reynolds  female          40
# 1275        1275                   Ben Mathis    Male          35
# 1276        1276                 Pat McFadden    male          52
# 1277        1277                Kieran Mullan    male           0
# 1278        1278                Sarah Quarmby  female          26
# 1279        1279              Stephen Kearney    Male           0
# 1280        1280                  Joy Squires  Female          63
# 1281        1281                 Robin Walker    Male          39
# 1282        1282                   Sue Hayman  female          55
# 1283        1283                Phill Roberts    male           0
# 1284        1284                  Clark Vasey    male           0
# 1285        1285               Barbara Keeley  female          65
# 1286        1286                 Iain Lindley    male          34
# 1287        1287                 Hazel Thorpe  female           0
# 1293  Conservative and Unionist Party                Wyre Forest    True
# 1294                     Labour Party                Wyre Forest   False
# 1295                     Labour Party     Wyre and Preston North   False
# 1296                Liberal Democrats     Wyre and Preston North   False
# 1297  Conservative and Unionist Party     Wyre and Preston North    True
# 1298  Conservative and Unionist Party  Wythenshawe and Sale East   False
# 1299                     Labour Party  Wythenshawe and Sale East    True
# 1300  Conservative and Unionist Party                     Yeovil    True
# 1301                     Labour Party                   Ynys Môn    True
# 1302                Liberal Democrats               York Central   False
# 1303                Liberal Democrats                 York Outer   False
#
#      twitter_username     twitter_user_id  tweets_count     ...       retweet  \
# 0            SKinnock           722347303          2617     ...         91268
# 1               CenLD          1872769464          2798     ...       3628547
# 2          sadievidal            19447175            22     ...         30248
# 3       GutoAberconwy  752820350371717120           335     ...         14791
# 4     Emily4Aberconwy            92363214           698     ...        562405
# 5      isobeldavidson          1553831654           335     ...          1606
# 6     Grace_E_OKeeffe  858789131622723584           183     ...        436998
# 7      OrrVinegoldLab  857290145795641344            11     ...           919
# 8       callumjodwyer            65415768          2593     ...       9513428
# 9      RossThomson_MP           539849453          2943     ...        223083
# 10            wilsjen            19650715           843     ...        908675
# 11    AirdrieShottsLP          3072556480           250     ...         49952
# 12      LeoDochertyUK           562385310           375     ...         91395
# 13        alanhilliar            52522161             1     ...            85
# 14       Gary_Puffett           254533424          2903     ...       2661854
# 15       JohnFisher_1           870198840           284     ...        529056
# 16          ablibdems           125151345             1     ...             1
# 17       morton_wendy           813678139           496     ...         64476
# 18       JaneBrophyLD          4099573113          2347     ...        174668
# 19     AndrewHWestern           274033876           696     ...       1831889
# 20      lauraknightly           305659027           147     ...        254629
# 21         MarkTamiMP          2278921206           891     ...         33807
# 22    CllrJamesDawson           330622644          2372     ...       1075608
# 23    KateSmithLibDem          2175891740             2     ...             1
# 24     Campbell4Angus  857757465391378432           132     ...        118830
# 25     Kirstene4Angus  701064119370326016           355     ...         12268
# 26       CliveSneddon          3156696916           338     ...          7987
# 27      marygwengriff            90275968           782     ...        260387
# 28      AlanReidAandB          2879189757            11     ...            15
# 29          LabourASD           370386782           543     ...         27952
# ...               ...                 ...           ...     ...           ...
# 1274   EmmaReynoldsMP            32965648          1576     ...        123189
# 1275         binny_uk            24467456          2550     ...       1483359
# 1276    patmcfaddenmp            25091518          1970     ...       1207406
# 1277   KieranMullanUK          2834640796             7     ...           175
# 1278          Alibdem          4758642640           295     ...         27828
# 1279  stephenakearney          4213022061           123     ...         41045
# 1280       JoySquires           391162297           982     ...        182443
# 1281  WalkerWorcester          1978270322          2841     ...        193909
# 1282       SueHayman1           580947925          1586     ...        673138
# 1283    phillroberts2          2561204678             5     ...         44476
# 1284       ClarkVasey          3244940967          1209     ...        167791
# 1285         KeeleyMP           331178901          2068     ...        809194
# 1286     cllrilindley            16667402          2775     ...       2600058
# 1287     hazel_thorpe           478839833          2844     ...        788263
# 1288   andrew4wrexham           115887294          2810     ...         59020
# 1289        IanCLucas           121762421          2849     ...        504546
# 1290     SteveBakerHW            15157283          2910     ...        386023
# 1284       660        435     900     573    0.359801  0.744417  0.473945
# 1285      6350        222    1903     348    0.107350  0.920213  0.168279
# 1286      1420        336    2536    1130    0.121081  0.913874  0.407207
# 1287       178         47    2644     299    0.016526  0.929677  0.105134
# 1288     12952        514    2657    1672    0.182918  0.945552  0.595018
# 1289      5948       1095    2174    1729    0.384345  0.763075  0.606880
# 1290      5665        363    2550     764    0.124742  0.876289  0.262543
# 1291        86         30     117      49    0.254237  0.991525  0.415254
# 1292        63         36      49      43    0.720000  0.980000  0.860000
# 1293       750        160    1346     191    0.118343  0.995562  0.141272
# 1294       114          3       5       4    0.600000  1.000000  0.800000
# 1295       200         37     144      63    0.250000  0.972973  0.425676
# 1296       840        456    1147     854    0.385787  0.970389  0.722504
# 1297      1587         94     832     302    0.112981  1.000000  0.362981
# 1298         5          4      39      12    0.097561  0.951220  0.292683
# 1299      5240        230    1466     591    0.147910  0.942765  0.380064
# 1300      4581        831    1851    1493    0.361776  0.805834  0.649978
# 1301      4061        606    2438     829    0.226457  0.911061  0.309791
# 1302      1129        202     949     351    0.192564  0.904671  0.334604
# 1303       611         60     167     182    0.289855  0.806763  0.879227
#
#       topic_count  topic_ratio
# 0            1150     0.033055
# 1            1199     0.029486
# 2               6     0.017910
# 3              78     0.016807
# 4             238     0.025895
# 5              65     0.018513
# 6              64     0.026846
# 7               5     0.041322
# 8             386     0.012933
# 9            1394     0.034360
# 10            237     0.021398
# 11             84     0.026889
# 12            130     0.027317
# 13              0     0.000000
# 14           1048     0.026918
# 15            155     0.044248
# 16              1     1.000000
# 17            147     0.021166
# 18            826     0.026574
# 19            184     0.019789
# 20             54     0.026380
# 21            293     0.024466
# 22            410     0.012314
# 23              0     0.000000
# 24             54     0.031634
# 25            182     0.040239
# 26            151     0.039333
# 27            284     0.028217
# 28              5     0.031646
# 29            288     0.044916
# ...           ...          ...
# 1274          828     0.042824
# 1275          504     0.014569
# 1276          817     0.031965
# 1277            4     0.037383
# 1278           91     0.030764
# 1279           22     0.013915
# 1280          305     0.022426
# 1281         1041     0.025698
# 1282          592     0.027921
# 1283            0     0.000000
# 1284          801     0.052994
# 1285         1001     0.035704
# 1286          685     0.016539
# 1287         1149     0.028651
# 1288          512     0.013071
# 1289          753     0.022363
# 1290         1369     0.036145
# 1291           43     0.028271
# 1292           22     0.037162
# 1293          682     0.036543
# 1294            2     0.035088
# 1295           68     0.035160
# 1296          227     0.014601
# 1297          340     0.029658
# 1298            7     0.011438
# 1299          526     0.025310
# 1300          987     0.032308
# 1301          632     0.016515
# 1302          413     0.026353
# 1303           60     0.022214
#
# [1304 rows x 22 columns]

# %%
###get topic list
def getMPList(ListFileName):
    #read the list file and build a list
    read_list = []

    fp = open(ListFileName, 'r')
    line = fp.readline()
    while line:
        word = line.strip()
#         w = word.lower()
        read_list.append(word)
        line = fp.readline()
    fp.close()
    return read_list

former_mp17 = getMPList('sitting_mp17.txt')

# %%
result_with_topic['former_MP'] = result_with_topic.name.apply(lambda x: 'yes' if x in former_mp17 else 'no')

# %%
result_with_topic.to_csv('All_data_large_2017_S.csv')
